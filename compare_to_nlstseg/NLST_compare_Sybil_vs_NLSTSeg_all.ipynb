# %% [markdown]
# <a href="https://colab.research.google.com/github/deepakri201/SR_for_NLST_Sybil/blob/main/compare_to_nlstseg/NLST_compare_Sybil_vs_NLSTSeg_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Compare all series that overlap
#
# later run comparison over all series, see which have bounding boxes and no seg, and vice versa
#
#
# Deepa Krishnaswamy
# Brigham and Women's Hospital
# October 2025

# %% [markdown]
# # Parameterization

# %%
#@title Enter your Project ID here
# initialize this variable with your Google Cloud Project ID!
project_name = "idc-external-018" #@param {type:"string"}

import os
os.environ["GCP_PROJECT_ID"] = project_name

# !gcloud config set project $project_name

from google.colab import auth
auth.authenticate_user()
# Out:
# Updated property [core/project].

# %% [markdown]
# # Environment setup

# %%
# !pip install idc-index
# Out:
# Collecting idc-index
#   Downloading idc_index-0.10.2-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from idc-index) (8.3.0)
# Collecting duckdb<=1.2.1,>=0.10.0 (from idc-index)
#   Downloading duckdb-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (966 bytes)
# Collecting idc-index-data==22.0.2 (from idc-index)
#   Downloading idc_index_data-22.0.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from idc-index) (25.0)
# Requirement already satisfied: pandas<=2.2.4 in /usr/local/lib/python3.12/dist-packages (from idc-index) (2.2.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from idc-index) (4.5.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from idc-index) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from idc-index) (18.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from idc-index) (2.32.4)
# Collecting s5cmd>=0.3.2 (from idc-index)
#   Downloading s5cmd-0.3.3-py3-none-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.0 kB)
# Collecting sphinx-click (from idc-index)
#   Downloading sphinx_click-6.1.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from idc-index) (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<=2.2.4->idc-index) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<=2.2.4->idc-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<=2.2.4->idc-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<=2.2.4->idc-index) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->idc-index) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->idc-index) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->idc-index) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->idc-index) (2025.10.5)
# Requirement already satisfied: sphinx>=4.0 in /usr/local/lib/python3.12/dist-packages (from sphinx-click->idc-index) (8.2.3)
# Requirement already satisfied: docutils in /usr/local/lib/python3.12/dist-packages (from sphinx-click->idc-index) (0.21.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<=2.2.4->idc-index) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (1.4.1)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sphinx>=4.0->sphinx-click->idc-index) (3.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from Jinja2>=3.1->sphinx>=4.0->sphinx-click->idc-index) (3.0.3)
# Downloading idc_index-0.10.2-py3-none-any.whl (27 kB)
# Downloading idc_index_data-22.0.2-py3-none-any.whl (82.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 MB 12.9 MB/s eta 0:00:00
# Downloading duckdb-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 61.1 MB/s eta 0:00:00
# Downloading s5cmd-0.3.3-py3-none-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 78.1 MB/s eta 0:00:00
# Downloading sphinx_click-6.1.0-py3-none-any.whl (8.9 kB)
# Installing collected packages: s5cmd, idc-index-data, duckdb, sphinx-click, idc-index
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
# Successfully installed duckdb-1.2.1 idc-index-0.10.2 idc-index-data-22.0.2 s5cmd-0.3.3 sphinx-click-6.1.0

# %%
import os
import sys
import time

import numpy as np
import pandas as pd
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

import json
from pathlib import Path

# %%
import matplotlib.patches as patches

# %%
from google.cloud import bigquery
from google.cloud import storage

# %%
import datetime

# %%
from idc_index import IDCClient

idc_client = IDCClient.client()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pydicom
import pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 16.2 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.1

# %% [markdown]
# # Find the series that have both a bounding box and a segmentation

# %%
# Get the Referenced SeriesInstanceUIDs of the Sybil bounding boxes
client_bq = bigquery.Client(project=project_name)
query = f"""
  SELECT
    DISTINCT(ReferencedSeriesInstanceUID)
  FROM
    `idc-external-018.sybil_and_nlstseg.bbox_measurements`
"""
df_sybil = client_bq.query(query).to_dataframe()

# Get the Referenced SeriesInstanceUIDs of the NLSTSeg
query = f"""
  SELECT
    DISTINCT(segmented_SeriesInstanceUID)
  FROM
    `idc-external-018.sybil_and_nlstseg.segmentations`
"""
df_nlstseg = client_bq.query(query).to_dataframe()

# Get the intersection
SeriesInstanceUIDs_list = list(set(df_sybil['ReferencedSeriesInstanceUID'].values) & set(df_nlstseg['segmented_SeriesInstanceUID'].values))

# Check
print('Sybil number of series: ' + str(len(df_sybil)))
print('NLSTSeg number of series: ' + str(len(df_nlstseg)))
print('Number of intersecting series: ' + str(len(SeriesInstanceUIDs_list)))
# Out:
# Sybil number of series: 970
# NLSTSeg number of series: 597
# Number of intersecting series: 402

# %% [markdown]
# # Get the overlapping slices

# %%
query = f"""
  SELECT
    *
  FROM
    `idc-external-018.sybil_and_nlstseg.bbox_measurements`
  WHERE
    ReferencedSeriesInstanceUID IN UNNEST(@series_list)
"""
job_config = bigquery.QueryJobConfig(query_parameters=[bigquery.ArrayQueryParameter("series_list", "STRING", SeriesInstanceUIDs_list)])
df_sybil_bbox = client_bq.query(query, job_config=job_config).to_dataframe()

# %%
df_sybil_bbox.head()
# Out:
#   PatientID                                   StudyInstanceUID  \
# 0    100147  1.2.840.113654.2.55.31958452963320032523273261...
# 1    100147  1.2.840.113654.2.55.31958452963320032523273261...
# 2    100147  1.2.840.113654.2.55.31958452963320032523273261...
# 3    100147  1.2.840.113654.2.55.31958452963320032523273261...
# 4    100147  1.2.840.113654.2.55.31958452963320032523273261...
#
#                                    SeriesInstanceUID  \
# 0  1.2.826.0.1.3680043.8.498.80137012981695130585...
# 1  1.2.826.0.1.3680043.8.498.80137012981695130585...
# 2  1.2.826.0.1.3680043.8.498.80137012981695130585...
# 3  1.2.826.0.1.3680043.8.498.80137012981695130585...
# 4  1.2.826.0.1.3680043.8.498.80137012981695130585...
#
#                                       SOPInstanceUID  \
# 0  1.2.826.0.1.3680043.8.498.25702787397259362445...
# 1  1.2.826.0.1.3680043.8.498.25702787397259362445...
# 2  1.2.826.0.1.3680043.8.498.25702787397259362445...
# 3  1.2.826.0.1.3680043.8.498.25702787397259362445...
# 4  1.2.826.0.1.3680043.8.498.25702787397259362445...
#
#                          ReferencedSeriesInstanceUID trackingIdentifier  \
# 0  1.2.840.113654.2.55.15708941008648745210499888...    Bounding box #1
# 1  1.2.840.113654.2.55.15708941008648745210499888...    Bounding box #2
# 2  1.2.840.113654.2.55.15708941008648745210499888...    Bounding box #3
# 3  1.2.840.113654.2.55.15708941008648745210499888...    Bounding box #4
# 4  1.2.840.113654.2.55.15708941008648745210499888...    Bounding box #5
#
#                             trackingUniqueIdentifier  \
# 0  1.2.826.0.1.3680043.8.498.19732880118785808469...
# 1  1.2.826.0.1.3680043.8.498.27663554135755923869...
# 2  1.2.826.0.1.3680043.8.498.45257385294575042278...
# 3  1.2.826.0.1.3680043.8.498.31896297182924717311...
# 4  1.2.826.0.1.3680043.8.498.21363506884817323687...
#
#                                              finding  \
# 0  {'CodeValue': '52988006', 'CodingSchemeDesigna...
# 1  {'CodeValue': '52988006', 'CodingSchemeDesigna...
# 2  {'CodeValue': '52988006', 'CodingSchemeDesigna...
# 3  {'CodeValue': '52988006', 'CodingSchemeDesigna...
# 4  {'CodeValue': '52988006', 'CodingSchemeDesigna...
#
#                                          findingSite  \
# 0  {'CodeValue': '39607008', 'CodingSchemeDesigna...
# 1  {'CodeValue': '39607008', 'CodingSchemeDesigna...
# 2  {'CodeValue': '39607008', 'CodingSchemeDesigna...
# 3  {'CodeValue': '39607008', 'CodingSchemeDesigna...
# 4  {'CodeValue': '39607008', 'CodingSchemeDesigna...
#
#                             ReferencedSOPInstanceUID  \
# 0  1.2.840.113654.2.55.79807002501189556016815093...
# 1  1.2.840.113654.2.55.15052476845087007628485738...
# 2  1.2.840.113654.2.55.32901662060934990548341662...
# 3  1.2.840.113654.2.55.21729370900780746886375992...
# 4  1.2.840.113654.2.55.19851369674160913596156868...
#
#                              ConceptNameCodeSequence GraphicType          x0  \
# 0  [{'CodeValue': '111030', 'CodingSchemeDesignat...    POLYLINE  130.021896
# 1  [{'CodeValue': '111030', 'CodingSchemeDesignat...    POLYLINE  130.000000
# 2  [{'CodeValue': '111030', 'CodingSchemeDesignat...    POLYLINE  129.000000
# 3  [{'CodeValue': '111030', 'CodingSchemeDesignat...    POLYLINE  129.000000
# 4  [{'CodeValue': '111030', 'CodingSchemeDesignat...    POLYLINE  129.000000
#
#            y0          x1          y1          x2          y2          x3  \
# 0  312.039795  172.815903  312.039795  172.815903  347.701508  130.021896
# 1  312.000000  171.000000  312.000000  171.000000  348.000000  130.000000
# 2  313.000000  169.000000  313.000000  169.000000  349.000000  129.000000
# 3  313.000000  167.000000  313.000000  167.000000  350.000000  129.000000
# 4  314.000000  166.000000  314.000000  166.000000  351.000000  129.000000
#
#            y3
# 0  347.701508
# 1  348.000000
# 2  349.000000
# 3  350.000000
# 4  351.000000

# %%
# Get a list of the Referenced SOPInstanceUIDs of the Sybil bounding boxes

query = f"""
  SELECT
    dicom_all.PatientID,
    dicom_all.StudyInstanceUID,
    rss.SeriesInstanceUID,
    ris.ReferencedSOPInstanceUID
  FROM
    `idc-external-018.sybil_and_nlstseg.dicom_all` AS dicom_all
  CROSS JOIN
    UNNEST(dicom_all.ReferencedSeriesSequence) AS rss
  CROSS JOIN
    UNNEST(rss.ReferencedInstanceSequence) AS ris
  WHERE
    rss.SeriesInstanceUID IN UNNEST(@series_list)
"""
job_config = bigquery.QueryJobConfig(query_parameters=[bigquery.ArrayQueryParameter("series_list", "STRING", SeriesInstanceUIDs_list)])
df_nlstseg_seg = client_bq.query(query, job_config=job_config).to_dataframe()

# # Get the intersection
# SOPInstanceUIDs_list = list(set(df_sybil_bbox['ReferencedSOPInstanceUID'].values ) & set(df_nlstseg_seg['ReferencedSOPInstanceUID'].values))

# # Check
# print('Sybil number of referenced SOPInstanceUIDs: ' + str(len(df_sybil_bbox)))
# print('NLSTSeg number of referenced SOPInstanceUIDs: ' + str(len(df_nlstseg_seg)))
# print('Number of intersecting referenced SOPInstanceUIDs: ' + str(len(SOPInstanceUIDs_list)))

# %%
df_nlstseg_seg.head()
# Out:
#   PatientID                                   StudyInstanceUID  \
# 0    102736  1.2.840.113654.2.55.23485103792480070136869664...
# 1    102736  1.2.840.113654.2.55.23485103792480070136869664...
# 2    120573  1.2.840.113654.2.55.60312645929603274507035783...
# 3    120573  1.2.840.113654.2.55.60312645929603274507035783...
# 4    114248  1.2.840.113654.2.55.14865377394025870860835319...
#
#                                    SeriesInstanceUID  \
# 0  1.2.840.113654.2.55.77451854363369829573866150...
# 1  1.2.840.113654.2.55.77451854363369829573866150...
# 2  1.2.840.113654.2.55.32568708984853805318844556...
# 3  1.2.840.113654.2.55.32568708984853805318844556...
# 4  1.2.840.113654.2.55.12363323410784959119051552...
#
#                             ReferencedSOPInstanceUID
# 0  1.2.840.113654.2.55.22633428721175074221864018...
# 1  1.2.840.113654.2.55.34019444235248186592925698...
# 2  1.2.840.113654.2.55.22650922629996972611142371...
# 3  1.2.840.113654.2.55.32515570644216935462720137...
# 4  1.2.840.113654.2.55.29006022640692810061379893...

# %%
len(df_nlstseg_seg)
# Out:
# 4998

# %% [markdown]
# # Get the overlap in terms of actual pixel segmentation and bounding box - so we can flag scans that don't have complete tumor coverage.

# %%
df_patient = df_nlstseg_seg.copy(deep=True)[['PatientID', 'StudyInstanceUID', 'SeriesInstanceUID']]
df_patient = df_patient.drop_duplicates(subset=['PatientID', 'StudyInstanceUID', 'SeriesInstanceUID'])
df_patient.head()

PatientID_list = df_patient['PatientID'].values
StudyInstanceUID_list = df_patient['StudyInstanceUID'].values
SeriesInstanceUID_list = df_patient['SeriesInstanceUID'].values

# %%
# We add the gcs_url of the SEG file to this dataframe
gcs_url_seg = [os.path.join("gs://nlstseg_seg_and_sr/seg", f + "_SEG.dcm") for f in SeriesInstanceUID_list]
df_patient['gcs_url_seg'] = gcs_url_seg

# %%
len(df_patient)
# Out:
# 402

# %%
df_patient.head()
# Out:
#   PatientID                                   StudyInstanceUID  \
# 0    102736  1.2.840.113654.2.55.23485103792480070136869664...
# 2    120573  1.2.840.113654.2.55.60312645929603274507035783...
# 4    114248  1.2.840.113654.2.55.14865377394025870860835319...
# 6    113623  1.2.840.113654.2.55.22482478647078478355738832...
# 9    102537  1.2.840.113654.2.55.17698629574705452327296269...
#
#                                    SeriesInstanceUID  \
# 0  1.2.840.113654.2.55.77451854363369829573866150...
# 2  1.2.840.113654.2.55.32568708984853805318844556...
# 4  1.2.840.113654.2.55.12363323410784959119051552...
# 6  1.2.840.113654.2.55.17412435624899643050868386...
# 9  1.2.840.113654.2.55.17923185272132498184218647...
#
#                                          gcs_url_seg
# 0  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...
# 2  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...
# 4  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...
# 6  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...
# 9  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...

# %%
# Download all the SEG files from the bucket for this list of series
seg_directory_bucket = "gs://nlstseg_seg_and_sr/seg"
seg_directory = "/content/seg"
if not os.path.isdir(seg_directory):
  os.mkdir(seg_directory)

# Create the text file to hold gsc_url
gcsurl_temp = df_patient["gcs_url_seg"]
gs_file_path = "gcs_paths.txt"
gcsurl_temp.to_csv(gs_file_path, header = False, index = False)

# !cat manifest.txt | gsutil -m cp -I .
# !cat gcs_paths.txt | gsutil -m cp -I $seg_directory
# Out:
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.77451854363369829573866150401935945777_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.3256870898485380531884455642265281171_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.123633234107849591190515522342469572867_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.174124356248996430508683867152648202173_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.179231852721324981842186473145321629778_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.182315093935481624682845229846809224632_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.38995485391900019876570761037952058249_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.158364186499334911697140176182635356136_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.135314423026715332810549867523376949749_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.333959368472243697306539144681085718022_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.205688193328322143786287645000299423375_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.80716887202718212912842134755481869828_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.204642191063326653170110007925732322027_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.32005491511751878907785232875733365323_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.337246498180183225505847852854636608611_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.131554014629074879725055125050225541536_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.144931383235854544235300790173_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.280645634420542648203290402777_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.315936508105811304217698316302_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.326325246098191006027436420248_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.187916168052143707748361859868934457191_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.213758672215327638179929291394926351146_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.11540944481901480924019938119296989447_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.202078761136036749161107553563389075803_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.198981735234109140872055852899557001028_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.265811533156606495950473119879580087587_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.232459064054253624772250053551839110752_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.312030893713712616757213977244096850146_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.81809749276986725587053210360651375677_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.175141405312830297022101030636287677783_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.14382674871619950799472325766084940706_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.98213040593693505162579915860735971212_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.144340766508502271029060627876045251510_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.320120460469255723293391943100324223254_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.158466220092524136496371772149930312991_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.926070962577152530576648493883_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.192525281608175837322789780307_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.328556977712236541287818198607_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.175817836062435210980057971444_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.339956946238032705972603308685416663482_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.195687615519561194715245096282403100906_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.84447557825092715693249482357262634235_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.118099385827111603176263458990659555444_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17658683864590510336787393836845418990_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.174639415508620935145028282277042780072_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.49839034697406949726005641395881606917_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.119018409217210401675509551230628494456_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.123800934642743115448994694971021310180_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.103164989352592098929741164632137395127_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.324222466647716155625000469242011339484_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.173358788996277876607007025414753328199_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.280652015329571311885707163360976739271_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.20260464352090956925306653731131974215_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.36720472879967990193144980615763182705_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.217802425509966403654479669956553198048_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.174815865605540072126627846390000187679_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.211850622695004227027857089558221518940_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.273747268704781042450389888241893976150_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.194100962498581744629324365001643858987_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.315901155485141710568107208522744119403_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.252790578163294500394363956440600203102_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.33050419981657925174979113934207159380_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.94518475546509771370984195173527757543_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.225893401562023672707560220661212937130_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.40305727010684967538867737864782266115_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.262564043997006039201662725545109911310_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.219933463752955637040480130954321726544_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.171025045496816499829908809908233964832_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.80557134350152339289139946609720557730_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.298012365445252708668937282753163582528_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.627929135391099950342760251760_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.309253156651422584290397669325778568792_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.650053797534074365337114411297_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.194354562095023448671282511635920859408_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.621779377940751615087414392379_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.125598864949686036444273683439_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.222261554379030963094799371916_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.297805958752394287945623151974_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.303195469219875859644940611845_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.144965022893191407663386785886_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.990172827664001291939530751684_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.179068386711781741405062504446_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.239054227238294741410265568772_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.401862589013349125493694494808_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.129921359485285227905335949620_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.227972196329718903717660021172_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.291893030174859756508765761855_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.153924221910814877136808476968_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.244483413823778426481268994927175193345_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.151736094660966670123489964024716942063_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.16111750182367908886746912872049323704_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.14162314108578666423704822512735867871_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.112005050407705221921489268378715630967_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.237560930829175677728490591999091180420_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.294423248031318124872302490007395358486_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.9891152751121069541185696923049096885_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.162822187424066537685643792190649946297_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.87797263584059817420422842408163180099_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.105508597935357050120573060055759818144_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.83049458161444568535575942046508951670_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.219098170002792961663484151881908979793_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.27330557752167762437527417985475091283_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.122971168483213702501252817806311025669_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.336730487527427251909409858213101119123_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.65288672934924396656060784644935830286_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.128811497746561400357955147775811342417_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.292417379275620347083895524863594772869_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.19197457608385641817198995765620969796_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.294983438880810048468659241971163483684_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.46266614602271282854322228698604669142_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.32496072008315898589920724459377473768_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.240210190823923620084664786958280422251_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.215926225076041414333338084890561111589_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.73154804189607782205657648688778767637_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.145741332869175592333239317825408351493_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.181630417793454766365488688006739846292_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.235141650950874282078131410152740797115_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.285908287366994103953414791693711341798_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.161305680565057257280628853676270391350_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.131677473662446160187267284953_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.183906244161753983993523861544_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.297665473749571577022552863644_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.328603427551231924197632135930_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.209285809611899739404379081173_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.103043553043570071841168962847_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.326652722868765760512456527653_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89033549933870375562545956359273139713_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.108736834907802190085065988996748090438_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.187488516158751447197073642392431374839_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.190772681372305047985301430611863350467_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.124449392974478871131429591436196671404_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.239065060077110334990368225803561003591_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.111450695377676523221372569079048491205_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.196622501102736074294090844425373743728_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.115175509770416319783772085325746597427_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.72429733128858640522374348303342889232_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.41091495790610194459724135577096464690_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.310609767809678441522963921292898109470_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.272450963487547376605393207916814195103_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.135968128742262057179054957067531073282_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.302248287903390299854039275975618817746_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.138166888591278777644190888301898501250_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.10212803674068251180698456742623207615_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.203089102823995295943633338597998288409_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.255298045766679977296292618717619397173_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.174138771322323571478875114343_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.261920674960844087932144874292577892490_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.169309936075332267797085665689677792004_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.331946355905898862508372677989078330393_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.261245792492590026839419370097967940966_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.55905915368746417680608580988846234578_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.339835645798758446691532724163_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.288574468796501890471931832631663421295_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.137284376304168395503445289171119065795_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.275710763012564703750919408555_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.133458457674502234162562970110_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.112251960264319977744085244552_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.164586013035960730340611327787_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.572219882663875211157944328868_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.630724833692378622177598798421_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.263827526097824451486081334589_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.138475685444403243712417929667_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.333884524290327041910062800676697116570_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.186718476017960288836619454001_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.60284554997549760208978021192752401714_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.322184916910148879927506802612139491767_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.291361586149710617044794254619653059093_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.125403043383466225171814830534052775879_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.116178619022139425999957920748644970996_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.238814541182280662161737112338918718341_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.207655924093883599445157375675238622055_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.289109210467811685626758090334149277572_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.157089410086487452104998883963678895145_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.729684157914255333591022131690_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.318323353513155615753961713305147161871_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.292479773624816414906106118083545163299_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.262292750379305468195976945717214632568_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.199280757164420714744169293221_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.274864899329458805359494586539_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.211572945097332183618302638652_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.216648624768018621300629367171_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.273496443861029715343178669949_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.225506400203554305763827757238_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.123262946416173131342778997641_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.224675142672761997512683643121_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.148800903815565314876573314988_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.115028254815852577487486355210417616410_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.225338428432733808973910426933_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.198678801664998611593159046987_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.323067664901890164304171820617478007365_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.62102832281866128335133952467331151018_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.201655506612925010288892835508800465315_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.297475359465669712309938774091708798816_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.265538721267645811445152681366443319503_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.119278381949136177284416234961643134266_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.198219587826015290649042601161_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.236423142679897697811855204133432442977_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.48603091694994608738318392223018348755_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.207640369878214224021885933204737576317_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.85571577504442452992028641567857501834_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.187625177555389677985422106104_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.128362675825191379264782186218670385164_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.206445619027777579146291436718278090156_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.312892052066020486212291113477170324390_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.244639088722574373221242820202_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.157204904209311171860286597352_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.127084246870040525887479880429_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.979854419582121445438454522940_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.172726594946631932238874333328_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.163631608039008231432551652759_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.244889788704777117265791693743_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.264823538108475401141178460625066576318_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.296339628639169155708773470329671748912_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.67095101227495808685302586770473894957_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89728807369105801595655166766945676208_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.65769548478962835586696130973853762477_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.232897582370228023625896718890064986745_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.14059028299195631370217959879698398394_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.202119798672919693443240353002_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.323804676332963457174235140303454945005_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.145745567373257852212520912375_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.231220162980458064663806103389419026678_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.98360851027786845429916202030579152093_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.1541837184580403203301129857398567723_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.64243829174890265599006202544885558888_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.85329497298127431588006646990027262565_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.302609055429861799803994589436_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.115306161827798335724668734142_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.247714574186092243007275105443_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.155830797336710173530941808595_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.335068937133704782371543277892_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.252746870598745190555002158435555893859_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.334561430487539693988609745570841610261_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.294795888751210912516507666864500510900_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.214483182570512319377495527619089952642_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.68648218892121690706317410635829132003_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.403437758939997784849726820932_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.257416692801824567109770633434577562863_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.758651454056241277004038704552_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.332576596933483367821758555164986814820_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.106004492444389108941417962052_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.130899157122224000055388738766_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.194978440150538663191132330353_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.143578662029406444612978007728_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17008868569894927008450364376626360407_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.161264160024979199783419898154_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.118722452529394350711166589345_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.133810826757692085945762413768_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.311135448859317568772411569963288214388_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89807759908895591032049335991091731003_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.20522329972429455898321727187899724639_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89477011945581920116417298062890129546_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.314395911906052434902081644014516651984_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.164768804662547412701807688620_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.165884453203631061279010869629665746850_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.261574503797213869314392805762561343844_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.170115213539867939035437973056423075675_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.63621237136724691963349850896317513699_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17879920116288438977407432295523363002_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.63873242866827151558814889186531561452_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89534960921624589282242592246163391311_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.281122741744238701551394451058782960222_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.135083646840972124662519033272893593787_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.619979304741157495229660017147_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.732617958380743426518581294837_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.96030936677299998289459301371355143208_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.321015447560879747152307811899265404393_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.299569302054927466999467983745_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.330420120433623992136851296394350684412_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.102679371468953163285569140890061441420_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.200932748333982227270105712503240293455_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.211327659440826290111901768213020906899_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.256819939386902184239905556344723042029_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.342418580706193998489061702827_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.30276220214859282848718508697843613549_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.202590990749233587270867529690119914374_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.223908149059930082550276878780455910207_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.207780613005490675500630966674_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.139132008311013694893031394896_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.274906584527642775644898336045_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.124662392740618336534191185780_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.112918986098180666980407474761214092582_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.169697003742573435409614923241347675640_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.18887628356060209734659781975646207647_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.140683453079065910695641432774813371083_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.162237089181970393467571471916_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.164750762258986107157881513300_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17220587240744170390288046904619698262_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.152351375083351137728883443485571695816_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.821126619905759469865221670961_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.302409961332202189020256932391_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.99981418632728007269752227847647500242_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.118240946395420474084011752812684423_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.129862789291463473130925568643344102761_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.46585009632538178829747577506479558322_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.274162140146233248111505261965574389069_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.248871178457179134133268428984990824357_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.231164885435494609343364648624058240444_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.153809938501803691882470179510604553143_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.265076645294278420451491835992_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.802863658154164773047723219988_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.276026819340563014906269522292_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.652542111531875496786085581001_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.711080093533188530839761726262_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.243584105004498617479171114963549864998_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.176071054683304110719613713146_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.163329702376772650635014222425_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.168559985013271056832798296931_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.300496294376345950127114445834693790599_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.243510052221089905476547647221_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.240324207329350237274075536816_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.300162360460384875273646744692_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.101314786969371795881789869088_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.65659509888424322769427058438403064906_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.81136962133262551156371928517766508555_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.238944838267171045713423118512022976877_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.972046923789567546322049002825_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.333811371558544670788812029369_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.22084245517968704647300402362399724489_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.114246821382240569611380795975517495817_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.55024213553689027610844746016919431304_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.55249935124047036645194998679497712331_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.79585603887413976622151425154743589691_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.234870527508599761640999671632707483702_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.133386609493277240203927332124127709601_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.933841618640476833036494357619_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.226720282857983435615951947960_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.282605138934435721988472315082_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.289613708626719952213368966039473341125_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.232991909979178037566082101940837619916_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.278537402659263177052326157620432088005_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.291681719373684904720555718424_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.211912645826213218933934057307_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.284978732490496848337467051474_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.303640943191823703361709653866526987877_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.209806477987078981088659965402559013159_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.317421001614200749620554087852_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.13335422647841201767208337101314418669_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.232131513785165026353474411362_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.263367954198156875547874810827609051599_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.113040386178547843571271236478024341696_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.291884765038938171737345289866_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.248367220149114779001236080527_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.217768437685736767355231176035_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.117168587881036721196334662566_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.180073756539777283491523882175_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.145215505102406333449483782713_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.176175057280389142500002693117_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.118365698813953167004356850681_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.302533635268177260202698156939540188162_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.175674334851122081937703890069307803316_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.78299330143623946343061044933747516_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.136132521671327053038928327413_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.315815227684601141210995143893765985256_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.449796649149718023106515279959_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.552954451305841457246485097814_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.38331112054215767893080935276683387701_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.170001881918406048131014011358_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.336832610089461934819661898582_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.181715871926844141208177392303_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.115451276425386762335739651324_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.130711389735203660002446393754174369152_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.128719895339498507728437515897_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.224817689169801013577098072503701293247_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.163513449124025050135426427567_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.940569451464186902108955404481_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.251522632416638635859677462723_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.216419520616220970553194986094193028074_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.200956373299047913742718734139_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.322861777944986297549227585914529686199_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.222684182749361389519417245884_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.195129470296841381925530422059553789327_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.102236556545478157092621557341658509914_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.246434579828531057425449543998861587365_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.38380760938863740334622103795226994737_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.174014234720705051674481406448_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.182434043811696504163378688408_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.81192991204494217085986885579563426789_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.288726058103780350347376743042404078910_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.102595981262437924743384555490348997068_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.676754769558561163655830587788_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.67851195947766274164353383578546290143_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.58920416584809699905140578786295322821_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.241924049353992159785903857377772231263_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.211693205194678397362913455586_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.674424600608887623087401566792_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.320594890074080794313231338281406181426_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17946222853752357522036394138531044474_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.317659298387497834095252537572_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.113963576659208997922505947759_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.277152651983810061753947249581_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.257830882183445545540953609532_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.131131828321708464413596959557_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.274095880606342862580083739420627901741_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.279100853054623203238704107156162119159_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.39516155940744949926070642539192360812_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.518652745898860177551735611820_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.785517485814092310381399550467_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.197537342578509830000233537889459327883_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.236581477720516135789038198297_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.184034787304891046495973007321_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.269922574105136237935136769376_SEG.dcm...
# / [402/402 files][163.6 MiB/163.6 MiB] 100% Done  12.4 MiB/s ETA 00:00:00
# Operation completed over 402 objects/163.6 MiB.

# %%
# Single mask/bbox
def tumor_fraction_in_box(mask, bbox):
  """
  mask: 2D numpy array (0/1 or bool) for tumor
  bbox: (xmin, ymin, xmax, ymax) in pixel coordinates
        (x = cols, y = rows)
  Returns: fraction of tumor voxels inside the box
  """
  xmin, ymin, xmax, ymax = bbox

  # clip to image bounds
  ymin = max(0, ymin); ymax = min(mask.shape[0], ymax)
  xmin = max(0, xmin); xmax = min(mask.shape[1], xmax)

  # box mask
  box_mask = np.zeros_like(mask, dtype=bool)
  box_mask[ymin:ymax, xmin:xmax] = True

  # intersection
  tumor_inside = np.logical_and(mask.astype(bool), box_mask)
  fraction = tumor_inside.sum() / mask.sum() if mask.sum() > 0 else np.nan

  return fraction

# List of masks/bboxes
def tumor_fraction_in_boxes(masks, bboxes):
    """
    Compute overall fraction of tumor voxels inside all boxes.

    Parameters
    ----------
    masks : list of 2D numpy arrays (bool or 0/1)
        Each mask corresponds to one slice.
    bboxes : list of tuples (xmin, ymin, xmax, ymax)
        Each bbox corresponds to the same slice index in masks.

    Returns
    -------
    fraction : float
        Overall fraction of tumor voxels inside all boxes across slices.
        Returns np.nan if no tumor voxels are present at all.
    """
    total_tumor_voxels = 0
    total_tumor_inside = 0

    for mask, bbox in zip(masks, bboxes):
        if mask is None or bbox is None:
            continue

        xmin, ymin, xmax, ymax = bbox

        # Clip to image bounds
        ymin = max(0, ymin); ymax = min(mask.shape[0], ymax)
        xmin = max(0, xmin); xmax = min(mask.shape[1], xmax)

        if ymin >= ymax or xmin >= xmax:
            continue  # skip degenerate boxes

        # Create box mask and compute intersection
        box_mask = np.zeros_like(mask, dtype=bool)
        box_mask[ymin:ymax, xmin:xmax] = True

        tumor_inside = np.logical_and(mask.astype(bool), box_mask)
        total_tumor_inside += tumor_inside.sum()
        total_tumor_voxels += mask.sum()

    if total_tumor_voxels == 0:
        return np.nan

    return total_tumor_inside / total_tumor_voxels

# %%
PatientID_list_temp = ["118672"]

# %%
### Calculate the overlap on a per series basis ###


df_overlap_all = pd.DataFrame()
print('Num patients: ' + str(len(PatientID_list)))

### Over each patient ###
for index, patient in enumerate(PatientID_list,1):
  print('*** On index: ' + str(index) + ' ***')
  print(patient)
  StudyInstanceUIDs = list(set(df_patient[df_patient['PatientID']==patient]['StudyInstanceUID'].values))

  ### Over each study ###
  for study in StudyInstanceUIDs:
    series = list(set(df_patient[df_patient['StudyInstanceUID']==study]['SeriesInstanceUID'].values))

    ### Over each series ###
    for series in series:

      ### Get the appropriate SEG file ###
      seg_filename = os.path.join("/content/seg", series + "_SEG.dcm")

      ### Get the referencedSOPInstanceUIDs and the mask indices ###
      # We know which slices have an overlap - by the referencedSOPInstanceUID
      # Now we need to get the pixel data for those slices.
      seg = pydicom.dcmread(seg_filename)
      SeriesInstanceUID_seg = seg.SeriesInstanceUID
      # Get the list of SegmentNumber and SegmentLabel
      segment_number_original_list = [f.SegmentNumber for f in seg.SegmentSequence]
      segment_label_original_list = [f.SegmentLabel for f in seg.SegmentSequence]
      # Get the pixel array data
      mask_data = seg.pixel_array
      # Need to get the per frame function groups - to know the referencedSOPInstanceUIDs
      pffg = seg.PerFrameFunctionalGroupsSequence
      num_slices_in_seg = len(pffg)
      print('num_slices_in_seg: ' + str(num_slices_in_seg))
      pffg_sop_list = []
      segment_number_list = []
      segment_label_list = []
      error_der_image_sequence = 0
      for n in range(0,num_slices_in_seg):
        try:
          sop = pffg[n].DerivationImageSequence[0].SourceImageSequence[0].ReferencedSOPInstanceUID
          segment_number = pffg[n].SegmentIdentificationSequence[0].ReferencedSegmentNumber
          # get the index of where the segment_number is in the segment_number_original_list
          segment_number_index = segment_number_original_list.index(segment_number)
          segment_label = segment_label_original_list[segment_number_index]
        except:
          print('ERROR: cannot access derivation image sequence')
          error_der_image_sequence = -1
          continue
        pffg_sop_list.append(sop)
        segment_number_list.append(segment_number)
        segment_label_list.append(segment_label)
      # Now create a dataframe with the SOPInstanceUID and the slice index into mask
      df_seg = pd.DataFrame()
      df_seg['SOPInstanceUID'] = pffg_sop_list
      df_seg['mask_slice'] = np.arange(0,len(pffg_sop_list))
      df_seg['SegmentNumber'] = segment_number_list
      df_seg['SegmentLabel'] = segment_label_list
      df_seg['num_of_slices_with_seg'] = [num_slices_in_seg] * len(pffg_sop_list)

      ### Now get the referencedSOPInstanceUID for the sybil bbox
      df_sybil_bbox_temp = df_sybil_bbox[df_sybil_bbox['ReferencedSeriesInstanceUID']==series]
      SeriesInstanceUID_bbox = df_sybil_bbox_temp['SeriesInstanceUID'].values[0]

      ### Now only keep the referencedSOPInstanceUIDs that overlap ###
      df_overlap = df_seg.merge(df_sybil_bbox, left_on='SOPInstanceUID', right_on='ReferencedSOPInstanceUID')
      df_overlap = df_overlap.drop(columns=['SOPInstanceUID_y'])
      df_overlap = df_overlap.rename(columns={'SOPInstanceUID_x':'SOPInstanceUID'})
      print('num slices with bbox: ' + str(len(df_overlap)))

      ### For each slice, calculate the overlap ###
      SOPInstanceUID_list = df_overlap['ReferencedSOPInstanceUID'].values
      mask_slice_list = df_overlap['mask_slice'].values

      mask_list = []
      bbox_list = []
      num_of_slices_with_bbox_list = []
      if (error_der_image_sequence==0):
        for SOPInstanceUID,mask_slice in zip(SOPInstanceUID_list,mask_slice_list):
          df_temp = df_overlap[df_overlap['ReferencedSOPInstanceUID']==SOPInstanceUID]
          x0 = df_temp['x0'].values[0]; y0 = df_temp['y0'].values[0]
          x1 = df_temp['x1'].values[0]; y1 = df_temp['y1'].values[0]
          x2 = df_temp['x2'].values[0]; y2 = df_temp['y2'].values[0]
          x3 = df_temp['x3'].values[0]; y3 = df_temp['y3'].values[0]
          width = x1 - x0 # can change later
          height = y2 - y1 # can change later
          xmin = x0 # can change later
          ymin = y0 # can change later
          xmax = xmin + width
          ymax = ymin + height
          bbox = [np.floor(xmin).astype(np.int16),
                  np.floor(ymin).astype(np.int16),
                  np.ceil(xmax).astype(np.int16),
                  np.ceil(ymax).astype(np.int16)]
          mask_list.append(mask_data[mask_slice,:,:])
          bbox_list.append(bbox)
          # num_of_slices_with_bbox_list.append(len(set(SOPInstanceUID_list)))
        # Calculate over the mask_list and bbox_list
        metric = tumor_fraction_in_boxes(mask_list, bbox_list)
        # We only keep unique series - as we want a metric per series instead of per SOPInstanceUID.
        # We need to group over SeriesInstanceUID as we want a list of the SegmentDescriptions
        df_overlap = (
          df_overlap.groupby(["PatientID", "StudyInstanceUID", "ReferencedSeriesInstanceUID"], as_index=False)
            .agg({"SegmentLabel": lambda x: sorted(x.unique().tolist())})
        )
        # df_overlap = df_overlap.drop_duplicates(subset=['PatientID', 'SeriesInstanceUID'], keep='first')
        # df_overlap = df_overlap.drop('SOPInstanceUID', axis=1)
        # Add to dataframe
        df_overlap['overlap_metric'] = metric
        # Add the number of slices that have seg
        df_overlap['num_of_slices_with_seg'] = num_slices_in_seg
        # Add the number of slices that have a bbox
        # df_overlap['num_of_slices_with_bbox'] = num_of_slices_with_bbox_list
        df_overlap['num_of_slices_with_bbox'] = len(set(SOPInstanceUID_list))
        # Add the number of slices that have a bounding box and tumor segmentation
        df_overlap['number_of_slices_with_bbox_and_seg'] = len(mask_list)
        # Add in the SeriesInstanceUID_seg
        # Add in the SeriesInstanceUID_bbox
        df_overlap['SeriesInstanceUID_seg'] = len(df_overlap) * [SeriesInstanceUID_seg]
        df_overlap['SeriesInstanceUID_bbox'] = len(df_overlap) * [SeriesInstanceUID_bbox]

  # Add to overall dataframe
  if (error_der_image_sequence==0):
    df_overlap_all = pd.concat([df_overlap_all, df_overlap], axis=0)



# Add the ohif url
viewer_url = ["https://viewers-sandbox-gha-testing.web.app/viewer/?StudyInstanceUIDs="
              + f
              + "&gcp=projects/idc-external-018/locations/us-central1/datasets/sybil_and_nlstseg/dicomStores/sybil_and_nlstseg"
              for f in df_overlap_all['StudyInstanceUID'].values]
df_overlap_all['viewer_url'] = viewer_url

# Add in the series specific viewer_url
series_viewer_url_list = ["https://viewers-sandbox-gha-testing.web.app/viewer/?StudyInstanceUIDs=" +
                          str(study) +  "&SeriesInstanceUIDs=" + str(ref_series) + ',' + str(seg_series) + ',' + str(bbox_series) +
                            "&gcp=projects/idc-external-018/locations/us-central1/datasets/sybil_and_nlstseg/dicomStores/sybil_and_nlstseg"
                          for study,ref_series,seg_series,bbox_series in
                          zip(df_overlap_all['StudyInstanceUID'].values,
                              df_overlap_all['ReferencedSeriesInstanceUID'].values,
                              df_overlap_all['SeriesInstanceUID_seg'].values,
                              df_overlap_all['SeriesInstanceUID_bbox'].values)]
df_overlap_all['series_viewer_url'] = series_viewer_url_list

# Keep specific columns
df_overlap_all = df_overlap_all[['PatientID', 'StudyInstanceUID', 'ReferencedSeriesInstanceUID', 'SegmentLabel',
                                 'num_of_slices_with_bbox', 'num_of_slices_with_seg',
                                 'overlap_metric', 'number_of_slices_with_bbox_and_seg',
                                 'SeriesInstanceUID_seg', 'SeriesInstanceUID_bbox',
                                 'viewer_url', 'series_viewer_url']]
df_overlap_all = df_overlap_all.sort_values(by=['PatientID', 'StudyInstanceUID', 'ReferencedSeriesInstanceUID'])
# df_overlap_all.rename({'ReferencedSeriesInstanceUID': 'SeriesInstanceUID'}, inplace=True)

# Save
df_overlap_all.to_csv("/content/sybil_and_nlstseg_overlap_per_series.csv")
# Out:
# Num patients: 402
# *** On index: 1 ***
# 102736
# num_slices_in_seg: 2
# num slices with bbox: 2
# *** On index: 2 ***
# 120573
# num_slices_in_seg: 2
# num slices with bbox: 2
# *** On index: 3 ***
# 114248
# num_slices_in_seg: 2
# num slices with bbox: 2
# *** On index: 4 ***
# 113623
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 5 ***
# 102537
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 6 ***
# 102267
# num_slices_in_seg: 3
# num slices with bbox: 2
# *** On index: 7 ***
# 100242
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 8 ***
# 134009
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 9 ***
# 129155
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 10 ***
# 124533
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 11 ***
# 124998
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 12 ***
# 107434
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 13 ***
# 106432
# num_slices_in_seg: 3
# num slices with bbox: 2
# *** On index: 14 ***
# 110716
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 15 ***
# 106000
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 16 ***
# 108352
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 17 ***
# 206732
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 18 ***
# 216940
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 19 ***
# 205687
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 20 ***
# 206687
# num_slices_in_seg: 3
# num slices with bbox: 3
# *** On index: 21 ***
# 118672
# num_slices_in_seg: 3
# num slices with bbox: 1
# *** On index: 22 ***
# 130133
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 23 ***
# 102660
# num_slices_in_seg: 4
# num slices with bbox: 3
# *** On index: 24 ***
# 133201
# num_slices_in_seg: 4
# num slices with bbox: 2
# *** On index: 25 ***
# 117612
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 26 ***
# 101692
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 27 ***
# 107328
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 28 ***
# 123072
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 29 ***
# 124486
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 30 ***
# 104208
# num_slices_in_seg: 4
# num slices with bbox: 3
# *** On index: 31 ***
# 105142
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 32 ***
# 121169
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 33 ***
# 126977
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 34 ***
# 114378
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 35 ***
# 131542
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 36 ***
# 216238
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 37 ***
# 200066
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 38 ***
# 217121
# num_slices_in_seg: 4
# num slices with bbox: 4
# *** On index: 39 ***
# 200683
# num_slices_in_seg: 4
# num slices with bbox: 0
# *** On index: 40 ***
# 120969
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 41 ***
# 130706
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 42 ***
# 131156
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 43 ***
# 133811
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 44 ***
# 119924
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 45 ***
# 124261
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 46 ***
# 100913
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 47 ***
# 102746
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 48 ***
# 121794
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 49 ***
# 110061
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 50 ***
# 109573
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 51 ***
# 106204
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 52 ***
# 106926
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 53 ***
# 123891
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 54 ***
# 130624
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 55 ***
# 132313
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 56 ***
# 101068
# num_slices_in_seg: 5
# num slices with bbox: 3
# *** On index: 57 ***
# 104182
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 58 ***
# 112258
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 59 ***
# 104063
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 60 ***
# 110356
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 61 ***
# 101066
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 62 ***
# 125727
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 63 ***
# 126520
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 64 ***
# 110253
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 65 ***
# 112073
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 66 ***
# 107610
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 67 ***
# 112893
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 68 ***
# 122866
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 69 ***
# 115524
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 70 ***
# 124190
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 71 ***
# 210581
# num_slices_in_seg: 5
# num slices with bbox: 4
# *** On index: 72 ***
# 126792
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 73 ***
# 203861
# num_slices_in_seg: 5
# num slices with bbox: 0
# *** On index: 74 ***
# 130315
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 75 ***
# 202165
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 76 ***
# 217482
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 77 ***
# 202822
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 78 ***
# 211494
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 79 ***
# 202268
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 80 ***
# 207391
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 81 ***
# 208589
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 82 ***
# 208735
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 83 ***
# 204870
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 84 ***
# 211707
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 85 ***
# 200969
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 86 ***
# 200056
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 87 ***
# 207691
# num_slices_in_seg: 5
# num slices with bbox: 5
# *** On index: 88 ***
# 204067
# num_slices_in_seg: 5
# num slices with bbox: 0
# *** On index: 89 ***
# 133076
# num_slices_in_seg: 6
# ERROR: cannot access derivation image sequence
# num slices with bbox: 4
# *** On index: 90 ***
# 123944
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 91 ***
# 103665
# num_slices_in_seg: 6
# num slices with bbox: 5
# *** On index: 92 ***
# 105974
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 93 ***
# 128944
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 94 ***
# 103507
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 95 ***
# 131174
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 96 ***
# 107058
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 97 ***
# 103344
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 98 ***
# 134491
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 99 ***
# 127992
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 100 ***
# 116289
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 101 ***
# 129627
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 102 ***
# 102161
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 103 ***
# 119358
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 104 ***
# 114746
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 105 ***
# 107133
# num_slices_in_seg: 6
# num slices with bbox: 4
# *** On index: 106 ***
# 130975
# num_slices_in_seg: 6
# num slices with bbox: 0
# *** On index: 107 ***
# 109532
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 108 ***
# 102581
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 109 ***
# 103232
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 110 ***
# 128940
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 111 ***
# 122117
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 112 ***
# 111454
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 113 ***
# 106971
# num_slices_in_seg: 6
# num slices with bbox: 5
# *** On index: 114 ***
# 117820
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 115 ***
# 133279
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 116 ***
# 131306
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 117 ***
# 121893
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 118 ***
# 123521
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 119 ***
# 133321
# num_slices_in_seg: 6
# num slices with bbox: 4
# *** On index: 120 ***
# 210371
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 121 ***
# 213630
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 122 ***
# 218307
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 123 ***
# 209140
# num_slices_in_seg: 6
# num slices with bbox: 5
# *** On index: 124 ***
# 204473
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 125 ***
# 209512
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 126 ***
# 205714
# num_slices_in_seg: 6
# num slices with bbox: 6
# *** On index: 127 ***
# 119474
# num_slices_in_seg: 6
# num slices with bbox: 3
# *** On index: 128 ***
# 134408
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 129 ***
# 110071
# num_slices_in_seg: 7
# num slices with bbox: 6
# *** On index: 130 ***
# 133786
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 131 ***
# 107791
# num_slices_in_seg: 7
# num slices with bbox: 5
# *** On index: 132 ***
# 134371
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 133 ***
# 129511
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 134 ***
# 108766
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 135 ***
# 116747
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 136 ***
# 118323
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 137 ***
# 131423
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 138 ***
# 100158
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 139 ***
# 101192
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 140 ***
# 119597
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 141 ***
# 122364
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 142 ***
# 111355
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 143 ***
# 126955
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 144 ***
# 114311
# num_slices_in_seg: 7
# num slices with bbox: 4
# *** On index: 145 ***
# 214822
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 146 ***
# 100703
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 147 ***
# 106498
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 148 ***
# 106364
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 149 ***
# 105340
# num_slices_in_seg: 7
# num slices with bbox: 4
# *** On index: 150 ***
# 132047
# num_slices_in_seg: 7
# num slices with bbox: 5
# *** On index: 151 ***
# 127890
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 152 ***
# 208446
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 153 ***
# 131486
# num_slices_in_seg: 7
# num slices with bbox: 6
# *** On index: 154 ***
# 127302
# num_slices_in_seg: 7
# num slices with bbox: 5
# *** On index: 155 ***
# 212293
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 156 ***
# 209874
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 157 ***
# 214975
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 158 ***
# 209865
# num_slices_in_seg: 7
# num slices with bbox: 6
# *** On index: 159 ***
# 217951
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 160 ***
# 209119
# num_slices_in_seg: 7
# num slices with bbox: 6
# *** On index: 161 ***
# 207830
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 162 ***
# 201726
# num_slices_in_seg: 7
# num slices with bbox: 7
# *** On index: 163 ***
# 200397
# num_slices_in_seg: 7
# num slices with bbox: 3
# *** On index: 164 ***
# 113952
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 165 ***
# 107521
# num_slices_in_seg: 8
# num slices with bbox: 6
# *** On index: 166 ***
# 129285
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 167 ***
# 106753
# num_slices_in_seg: 8
# num slices with bbox: 7
# *** On index: 168 ***
# 118664
# num_slices_in_seg: 8
# num slices with bbox: 7
# *** On index: 169 ***
# 104564
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 170 ***
# 132227
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 171 ***
# 123066
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 172 ***
# 116137
# num_slices_in_seg: 8
# num slices with bbox: 7
# *** On index: 173 ***
# 100147
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 174 ***
# 212202
# num_slices_in_seg: 8
# num slices with bbox: 3
# *** On index: 175 ***
# 130655
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 176 ***
# 126698
# num_slices_in_seg: 8
# num slices with bbox: 0
# *** On index: 177 ***
# 130467
# num_slices_in_seg: 8
# num slices with bbox: 0
# *** On index: 178 ***
# 218013
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 179 ***
# 212222
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 180 ***
# 214923
# num_slices_in_seg: 8
# num slices with bbox: 0
# *** On index: 181 ***
# 203791
# num_slices_in_seg: 8
# num slices with bbox: 7
# *** On index: 182 ***
# 201674
# num_slices_in_seg: 8
# num slices with bbox: 7
# *** On index: 183 ***
# 215151
# num_slices_in_seg: 8
# num slices with bbox: 7
# *** On index: 184 ***
# 202611
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 185 ***
# 206564
# num_slices_in_seg: 8
# num slices with bbox: 7
# *** On index: 186 ***
# 210090
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 187 ***
# 102388
# num_slices_in_seg: 8
# num slices with bbox: 8
# *** On index: 188 ***
# 206737
# num_slices_in_seg: 8
# num slices with bbox: 6
# *** On index: 189 ***
# 213734
# num_slices_in_seg: 8
# num slices with bbox: 4
# *** On index: 190 ***
# 111243
# num_slices_in_seg: 9
# num slices with bbox: 0
# *** On index: 191 ***
# 112235
# num_slices_in_seg: 9
# num slices with bbox: 8
# *** On index: 192 ***
# 119839
# num_slices_in_seg: 9
# num slices with bbox: 7
# *** On index: 193 ***
# 118560
# num_slices_in_seg: 9
# num slices with bbox: 9
# *** On index: 194 ***
# 121004
# num_slices_in_seg: 9
# num slices with bbox: 8
# *** On index: 195 ***
# 102658
# num_slices_in_seg: 9
# num slices with bbox: 7
# *** On index: 196 ***
# 204878
# num_slices_in_seg: 9
# num slices with bbox: 8
# *** On index: 197 ***
# 105562
# num_slices_in_seg: 9
# num slices with bbox: 4
# *** On index: 198 ***
# 121469
# num_slices_in_seg: 9
# num slices with bbox: 7
# *** On index: 199 ***
# 120954
# num_slices_in_seg: 9
# num slices with bbox: 8
# *** On index: 200 ***
# 105352
# num_slices_in_seg: 9
# num slices with bbox: 8
# *** On index: 201 ***
# 214640
# num_slices_in_seg: 9
# num slices with bbox: 6
# *** On index: 202 ***
# 120708
# num_slices_in_seg: 9
# num slices with bbox: 9
# *** On index: 203 ***
# 107561
# num_slices_in_seg: 9
# num slices with bbox: 8
# *** On index: 204 ***
# 104363
# num_slices_in_seg: 9
# num slices with bbox: 8
# *** On index: 205 ***
# 207786
# num_slices_in_seg: 9
# num slices with bbox: 6
# *** On index: 206 ***
# 213860
# num_slices_in_seg: 9
# num slices with bbox: 8
# *** On index: 207 ***
# 207869
# num_slices_in_seg: 9
# num slices with bbox: 7
# *** On index: 208 ***
# 213544
# num_slices_in_seg: 9
# num slices with bbox: 9
# *** On index: 209 ***
# 201979
# num_slices_in_seg: 9
# num slices with bbox: 9
# *** On index: 210 ***
# 205046
# num_slices_in_seg: 9
# num slices with bbox: 9
# *** On index: 211 ***
# 206354
# num_slices_in_seg: 9
# num slices with bbox: 8
# *** On index: 212 ***
# 100658
# num_slices_in_seg: 9
# num slices with bbox: 5
# *** On index: 213 ***
# 128651
# num_slices_in_seg: 10
# num slices with bbox: 9
# *** On index: 214 ***
# 104168
# num_slices_in_seg: 10
# num slices with bbox: 5
# *** On index: 215 ***
# 126999
# num_slices_in_seg: 10
# num slices with bbox: 10
# *** On index: 216 ***
# 124864
# num_slices_in_seg: 10
# num slices with bbox: 9
# *** On index: 217 ***
# 129553
# num_slices_in_seg: 10
# num slices with bbox: 9
# *** On index: 218 ***
# 102266
# num_slices_in_seg: 10
# num slices with bbox: 10
# *** On index: 219 ***
# 207347
# num_slices_in_seg: 10
# num slices with bbox: 10
# *** On index: 220 ***
# 100570
# num_slices_in_seg: 10
# num slices with bbox: 7
# *** On index: 221 ***
# 209184
# num_slices_in_seg: 10
# num slices with bbox: 9
# *** On index: 222 ***
# 107682
# num_slices_in_seg: 10
# num slices with bbox: 8
# *** On index: 223 ***
# 101834
# num_slices_in_seg: 10
# num slices with bbox: 8
# *** On index: 224 ***
# 103621
# num_slices_in_seg: 10
# num slices with bbox: 8
# *** On index: 225 ***
# 109616
# num_slices_in_seg: 10
# num slices with bbox: 9
# *** On index: 226 ***
# 127923
# num_slices_in_seg: 10
# num slices with bbox: 10
# *** On index: 227 ***
# 208944
# num_slices_in_seg: 10
# num slices with bbox: 8
# *** On index: 228 ***
# 200674
# num_slices_in_seg: 10
# num slices with bbox: 8
# *** On index: 229 ***
# 214553
# num_slices_in_seg: 10
# num slices with bbox: 10
# *** On index: 230 ***
# 217877
# num_slices_in_seg: 10
# num slices with bbox: 7
# *** On index: 231 ***
# 202976
# num_slices_in_seg: 10
# num slices with bbox: 10
# *** On index: 232 ***
# 112289
# num_slices_in_seg: 10
# num slices with bbox: 7
# *** On index: 233 ***
# 108245
# num_slices_in_seg: 11
# num slices with bbox: 11
# *** On index: 234 ***
# 116798
# num_slices_in_seg: 11
# num slices with bbox: 6
# *** On index: 235 ***
# 101287
# num_slices_in_seg: 11
# num slices with bbox: 8
# *** On index: 236 ***
# 117502
# num_slices_in_seg: 11
# num slices with bbox: 10
# *** On index: 237 ***
# 211893
# num_slices_in_seg: 11
# num slices with bbox: 11
# *** On index: 238 ***
# 115571
# num_slices_in_seg: 11
# num slices with bbox: 10
# *** On index: 239 ***
# 201641
# num_slices_in_seg: 11
# num slices with bbox: 10
# *** On index: 240 ***
# 103760
# num_slices_in_seg: 11
# num slices with bbox: 10
# *** On index: 241 ***
# 214419
# num_slices_in_seg: 11
# num slices with bbox: 9
# *** On index: 242 ***
# 211570
# num_slices_in_seg: 11
# num slices with bbox: 0
# *** On index: 243 ***
# 215101
# num_slices_in_seg: 11
# num slices with bbox: 9
# *** On index: 244 ***
# 203288
# num_slices_in_seg: 11
# num slices with bbox: 11
# *** On index: 245 ***
# 120570
# num_slices_in_seg: 11
# num slices with bbox: 6
# *** On index: 246 ***
# 217203
# num_slices_in_seg: 11
# num slices with bbox: 11
# *** On index: 247 ***
# 205900
# num_slices_in_seg: 11
# num slices with bbox: 11
# *** On index: 248 ***
# 217438
# num_slices_in_seg: 11
# num slices with bbox: 11
# *** On index: 249 ***
# 117601
# num_slices_in_seg: 12
# num slices with bbox: 9
# *** On index: 250 ***
# 117799
# num_slices_in_seg: 12
# num slices with bbox: 9
# *** On index: 251 ***
# 132036
# num_slices_in_seg: 12
# num slices with bbox: 12
# *** On index: 252 ***
# 114541
# num_slices_in_seg: 12
# num slices with bbox: 7
# *** On index: 253 ***
# 104815
# num_slices_in_seg: 12
# num slices with bbox: 12
# *** On index: 254 ***
# 214907
# num_slices_in_seg: 12
# num slices with bbox: 12
# *** On index: 255 ***
# 121099
# num_slices_in_seg: 12
# num slices with bbox: 5
# *** On index: 256 ***
# 131657
# num_slices_in_seg: 12
# num slices with bbox: 10
# *** On index: 257 ***
# 110817
# num_slices_in_seg: 12
# num slices with bbox: 9
# *** On index: 258 ***
# 106591
# num_slices_in_seg: 12
# num slices with bbox: 10
# *** On index: 259 ***
# 101387
# num_slices_in_seg: 12
# num slices with bbox: 12
# *** On index: 260 ***
# 130033
# num_slices_in_seg: 12
# num slices with bbox: 11
# *** On index: 261 ***
# 120701
# num_slices_in_seg: 12
# num slices with bbox: 10
# *** On index: 262 ***
# 110196
# num_slices_in_seg: 12
# num slices with bbox: 10
# *** On index: 263 ***
# 113814
# num_slices_in_seg: 12
# num slices with bbox: 8
# *** On index: 264 ***
# 216978
# num_slices_in_seg: 12
# num slices with bbox: 7
# *** On index: 265 ***
# 205781
# num_slices_in_seg: 12
# num slices with bbox: 11
# *** On index: 266 ***
# 108611
# num_slices_in_seg: 12
# num slices with bbox: 6
# *** On index: 267 ***
# 118713
# num_slices_in_seg: 12
# num slices with bbox: 7
# *** On index: 268 ***
# 203581
# num_slices_in_seg: 12
# num slices with bbox: 9
# *** On index: 269 ***
# 104778
# num_slices_in_seg: 13
# num slices with bbox: 12
# *** On index: 270 ***
# 101397
# num_slices_in_seg: 13
# num slices with bbox: 6
# *** On index: 271 ***
# 120070
# num_slices_in_seg: 13
# num slices with bbox: 12
# *** On index: 272 ***
# 119496
# num_slices_in_seg: 13
# num slices with bbox: 10
# *** On index: 273 ***
# 112851
# num_slices_in_seg: 13
# num slices with bbox: 11
# *** On index: 274 ***
# 132386
# num_slices_in_seg: 13
# num slices with bbox: 10
# *** On index: 275 ***
# 215930
# num_slices_in_seg: 13
# num slices with bbox: 11
# *** On index: 276 ***
# 112901
# num_slices_in_seg: 13
# num slices with bbox: 11
# *** On index: 277 ***
# 113176
# num_slices_in_seg: 13
# num slices with bbox: 7
# *** On index: 278 ***
# 203607
# num_slices_in_seg: 13
# num slices with bbox: 11
# *** On index: 279 ***
# 213754
# num_slices_in_seg: 13
# num slices with bbox: 12
# *** On index: 280 ***
# 215394
# num_slices_in_seg: 13
# num slices with bbox: 12
# *** On index: 281 ***
# 209831
# num_slices_in_seg: 13
# num slices with bbox: 13
# *** On index: 282 ***
# 131611
# num_slices_in_seg: 13
# num slices with bbox: 6
# *** On index: 283 ***
# 108670
# num_slices_in_seg: 14
# num slices with bbox: 12
# *** On index: 284 ***
# 106553
# num_slices_in_seg: 14
# num slices with bbox: 14
# *** On index: 285 ***
# 130942
# num_slices_in_seg: 14
# num slices with bbox: 14
# *** On index: 286 ***
# 212379
# num_slices_in_seg: 14
# num slices with bbox: 11
# *** On index: 287 ***
# 205405
# num_slices_in_seg: 14
# num slices with bbox: 13
# *** On index: 288 ***
# 110866
# num_slices_in_seg: 14
# num slices with bbox: 11
# *** On index: 289 ***
# 122590
# num_slices_in_seg: 14
# num slices with bbox: 10
# *** On index: 290 ***
# 204694
# num_slices_in_seg: 14
# num slices with bbox: 0
# *** On index: 291 ***
# 213442
# num_slices_in_seg: 14
# num slices with bbox: 14
# *** On index: 292 ***
# 106194
# num_slices_in_seg: 14
# num slices with bbox: 9
# *** On index: 293 ***
# 123247
# num_slices_in_seg: 14
# num slices with bbox: 14
# *** On index: 294 ***
# 104683
# num_slices_in_seg: 14
# num slices with bbox: 3
# *** On index: 295 ***
# 118248
# num_slices_in_seg: 15
# num slices with bbox: 13
# *** On index: 296 ***
# 107002
# num_slices_in_seg: 15
# num slices with bbox: 9
# *** On index: 297 ***
# 109852
# num_slices_in_seg: 15
# num slices with bbox: 15
# *** On index: 298 ***
# 108543
# num_slices_in_seg: 15
# num slices with bbox: 12
# *** On index: 299 ***
# 107151
# num_slices_in_seg: 15
# num slices with bbox: 6
# *** On index: 300 ***
# 212863
# num_slices_in_seg: 15
# num slices with bbox: 15
# *** On index: 301 ***
# 207526
# num_slices_in_seg: 15
# num slices with bbox: 15
# *** On index: 302 ***
# 215677
# num_slices_in_seg: 15
# num slices with bbox: 15
# *** On index: 303 ***
# 209412
# num_slices_in_seg: 15
# num slices with bbox: 13
# *** On index: 304 ***
# 203536
# num_slices_in_seg: 15
# num slices with bbox: 13
# *** On index: 305 ***
# 122025
# num_slices_in_seg: 15
# num slices with bbox: 8
# *** On index: 306 ***
# 210419
# num_slices_in_seg: 15
# num slices with bbox: 14
# *** On index: 307 ***
# 214350
# num_slices_in_seg: 16
# num slices with bbox: 15
# *** On index: 308 ***
# 203500
# num_slices_in_seg: 16
# num slices with bbox: 14
# *** On index: 309 ***
# 213753
# num_slices_in_seg: 16
# num slices with bbox: 8
# *** On index: 310 ***
# 111487
# num_slices_in_seg: 16
# num slices with bbox: 13
# *** On index: 311 ***
# 203125
# num_slices_in_seg: 16
# num slices with bbox: 16
# *** On index: 312 ***
# 211918
# num_slices_in_seg: 16
# num slices with bbox: 15
# *** On index: 313 ***
# 216399
# num_slices_in_seg: 16
# num slices with bbox: 16
# *** On index: 314 ***
# 104248
# num_slices_in_seg: 16
# num slices with bbox: 14
# *** On index: 315 ***
# 100518
# num_slices_in_seg: 17
# num slices with bbox: 0
# *** On index: 316 ***
# 134088
# num_slices_in_seg: 17
# num slices with bbox: 6
# *** On index: 317 ***
# 208294
# num_slices_in_seg: 17
# num slices with bbox: 0
# *** On index: 318 ***
# 201528
# num_slices_in_seg: 17
# num slices with bbox: 17
# *** On index: 319 ***
# 111859
# num_slices_in_seg: 18
# num slices with bbox: 15
# *** On index: 320 ***
# 131910
# num_slices_in_seg: 18
# num slices with bbox: 18
# *** On index: 321 ***
# 119326
# num_slices_in_seg: 18
# num slices with bbox: 18
# *** On index: 322 ***
# 110021
# num_slices_in_seg: 18
# num slices with bbox: 12
# *** On index: 323 ***
# 121333
# num_slices_in_seg: 18
# num slices with bbox: 13
# *** On index: 324 ***
# 114798
# num_slices_in_seg: 18
# num slices with bbox: 16
# *** On index: 325 ***
# 107052
# num_slices_in_seg: 18
# num slices with bbox: 15
# *** On index: 326 ***
# 213046
# num_slices_in_seg: 18
# num slices with bbox: 15
# *** On index: 327 ***
# 218510
# num_slices_in_seg: 18
# num slices with bbox: 17
# *** On index: 328 ***
# 209029
# num_slices_in_seg: 18
# num slices with bbox: 18
# *** On index: 329 ***
# 113918
# num_slices_in_seg: 19
# num slices with bbox: 18
# *** On index: 330 ***
# 105012
# num_slices_in_seg: 19
# num slices with bbox: 11
# *** On index: 331 ***
# 122135
# num_slices_in_seg: 19
# num slices with bbox: 19
# *** On index: 332 ***
# 217245
# num_slices_in_seg: 19
# num slices with bbox: 15
# *** On index: 333 ***
# 208430
# num_slices_in_seg: 19
# num slices with bbox: 14
# *** On index: 334 ***
# 209095
# num_slices_in_seg: 19
# num slices with bbox: 7
# *** On index: 335 ***
# 127399
# num_slices_in_seg: 20
# num slices with bbox: 19
# *** On index: 336 ***
# 134493
# num_slices_in_seg: 20
# num slices with bbox: 19
# *** On index: 337 ***
# 204711
# num_slices_in_seg: 20
# num slices with bbox: 20
# *** On index: 338 ***
# 117534
# num_slices_in_seg: 20
# num slices with bbox: 8
# *** On index: 339 ***
# 203087
# num_slices_in_seg: 20
# num slices with bbox: 5
# *** On index: 340 ***
# 126836
# num_slices_in_seg: 21
# num slices with bbox: 21
# *** On index: 341 ***
# 128156
# num_slices_in_seg: 21
# num slices with bbox: 17
# *** On index: 342 ***
# 200628
# num_slices_in_seg: 21
# num slices with bbox: 20
# *** On index: 343 ***
# 203908
# num_slices_in_seg: 21
# num slices with bbox: 21
# *** On index: 344 ***
# 212419
# num_slices_in_seg: 21
# num slices with bbox: 20
# *** On index: 345 ***
# 211677
# num_slices_in_seg: 21
# num slices with bbox: 9
# *** On index: 346 ***
# 209306
# num_slices_in_seg: 21
# num slices with bbox: 21
# *** On index: 347 ***
# 205089
# num_slices_in_seg: 21
# num slices with bbox: 21
# *** On index: 348 ***
# 217501
# num_slices_in_seg: 21
# num slices with bbox: 21
# *** On index: 349 ***
# 201465
# num_slices_in_seg: 22
# num slices with bbox: 35
# *** On index: 350 ***
# 120410
# num_slices_in_seg: 22
# num slices with bbox: 21
# *** On index: 351 ***
# 119818
# num_slices_in_seg: 22
# num slices with bbox: 0
# *** On index: 352 ***
# 116810
# num_slices_in_seg: 22
# num slices with bbox: 24
# *** On index: 353 ***
# 213972
# num_slices_in_seg: 22
# num slices with bbox: 19
# *** On index: 354 ***
# 105771
# num_slices_in_seg: 23
# num slices with bbox: 13
# *** On index: 355 ***
# 214472
# num_slices_in_seg: 23
# num slices with bbox: 17
# *** On index: 356 ***
# 202014
# num_slices_in_seg: 24
# num slices with bbox: 20
# *** On index: 357 ***
# 112285
# num_slices_in_seg: 24
# num slices with bbox: 12
# *** On index: 358 ***
# 212900
# num_slices_in_seg: 24
# num slices with bbox: 21
# *** On index: 359 ***
# 209116
# num_slices_in_seg: 24
# num slices with bbox: 17
# *** On index: 360 ***
# 207431
# num_slices_in_seg: 24
# num slices with bbox: 6
# *** On index: 361 ***
# 210754
# num_slices_in_seg: 24
# num slices with bbox: 12
# *** On index: 362 ***
# 109189
# num_slices_in_seg: 26
# num slices with bbox: 22
# *** On index: 363 ***
# 207954
# num_slices_in_seg: 26
# num slices with bbox: 26
# *** On index: 364 ***
# 127298
# num_slices_in_seg: 27
# num slices with bbox: 15
# *** On index: 365 ***
# 200931
# num_slices_in_seg: 27
# num slices with bbox: 27
# *** On index: 366 ***
# 204421
# num_slices_in_seg: 27
# num slices with bbox: 14
# *** On index: 367 ***
# 204197
# num_slices_in_seg: 28
# num slices with bbox: 27
# *** On index: 368 ***
# 114182
# num_slices_in_seg: 28
# num slices with bbox: 22
# *** On index: 369 ***
# 210497
# num_slices_in_seg: 28
# num slices with bbox: 27
# *** On index: 370 ***
# 107030
# num_slices_in_seg: 28
# num slices with bbox: 18
# *** On index: 371 ***
# 205591
# num_slices_in_seg: 28
# num slices with bbox: 21
# *** On index: 372 ***
# 122226
# num_slices_in_seg: 28
# num slices with bbox: 6
# *** On index: 373 ***
# 126446
# num_slices_in_seg: 28
# num slices with bbox: 0
# *** On index: 374 ***
# 125663
# num_slices_in_seg: 29
# num slices with bbox: 26
# *** On index: 375 ***
# 111221
# num_slices_in_seg: 29
# num slices with bbox: 13
# *** On index: 376 ***
# 216793
# num_slices_in_seg: 29
# num slices with bbox: 23
# *** On index: 377 ***
# 207366
# num_slices_in_seg: 29
# num slices with bbox: 15
# *** On index: 378 ***
# 123993
# num_slices_in_seg: 30
# num slices with bbox: 21
# *** On index: 379 ***
# 105540
# num_slices_in_seg: 30
# num slices with bbox: 15
# *** On index: 380 ***
# 119029
# num_slices_in_seg: 30
# num slices with bbox: 16
# *** On index: 381 ***
# 218391
# num_slices_in_seg: 30
# num slices with bbox: 30
# *** On index: 382 ***
# 120981
# num_slices_in_seg: 31
# num slices with bbox: 18
# *** On index: 383 ***
# 128534
# num_slices_in_seg: 32
# num slices with bbox: 0
# *** On index: 384 ***
# 102806
# num_slices_in_seg: 34
# num slices with bbox: 34
# *** On index: 385 ***
# 216422
# num_slices_in_seg: 34
# num slices with bbox: 21
# *** On index: 386 ***
# 203010
# num_slices_in_seg: 35
# num slices with bbox: 30
# *** On index: 387 ***
# 121337
# num_slices_in_seg: 36
# num slices with bbox: 24
# *** On index: 388 ***
# 103703
# num_slices_in_seg: 37
# num slices with bbox: 22
# *** On index: 389 ***
# 218368
# num_slices_in_seg: 38
# num slices with bbox: 31
# *** On index: 390 ***
# 212718
# num_slices_in_seg: 38
# num slices with bbox: 29
# *** On index: 391 ***
# 203759
# num_slices_in_seg: 41
# num slices with bbox: 24
# *** On index: 392 ***
# 204909
# num_slices_in_seg: 43
# num slices with bbox: 36
# *** On index: 393 ***
# 201275
# num_slices_in_seg: 44
# num slices with bbox: 44
# *** On index: 394 ***
# 114122
# num_slices_in_seg: 45
# num slices with bbox: 33
# *** On index: 395 ***
# 112041
# num_slices_in_seg: 46
# num slices with bbox: 6
# *** On index: 396 ***
# 115962
# num_slices_in_seg: 46
# num slices with bbox: 42
# *** On index: 397 ***
# 218357
# num_slices_in_seg: 46
# num slices with bbox: 46
# *** On index: 398 ***
# 203166
# num_slices_in_seg: 57
# num slices with bbox: 56
# *** On index: 399 ***
# 119843
# num_slices_in_seg: 62
# num slices with bbox: 19
# *** On index: 400 ***
# 200701
# num_slices_in_seg: 86
# num slices with bbox: 37
# *** On index: 401 ***
# 215002
# num_slices_in_seg: 98
# num slices with bbox: 84
# *** On index: 402 ***
# 217780
# num_slices_in_seg: 99
# num slices with bbox: 33

# %%
df_overlap
# Out:
#   PatientID                                   StudyInstanceUID  \
# 0    217780  1.3.6.1.4.1.14519.5.2.1.7009.9004.743323274081...
#
#                          ReferencedSeriesInstanceUID  \
# 0  1.3.6.1.4.1.14519.5.2.1.7009.9004.269922574105...
#
#                                    SegmentLabel  overlap_metric  \
# 0  [Lesion 1 - Tumor - Upper lobe of left lung]        0.982765
#
#    num_of_slices_with_bbox  number_of_slices_with_bbox_and_seg  \
# 0                       33                                  33
#
#                                SeriesInstanceUID_seg  \
# 0  1.2.276.0.7230010.3.1.3.481037312.602215.17612...
#
#                               SeriesInstanceUID_bbox
# 0  1.2.826.0.1.3680043.8.498.55382655415626102610...

# %%
df_overlap
# Out:
#   PatientID                                   StudyInstanceUID  \
# 0    102736  1.2.840.113654.2.55.23485103792480070136869664...
#
#                          ReferencedSeriesInstanceUID  \
# 0  1.2.840.113654.2.55.77451854363369829573866150...
#
#                                    SegmentLabel  overlap_metric
# 0  [Lesion 1 - Tumor - Upper lobe of left lung]             1.0

# %%
num_of_slices_with_bbox_list
# Out:
# [2, 2]

# %% [markdown]
# # OLD - Get the overlap in terms of actual pixel segmentation and bounding box

# %%
df_patient = df_nlstseg_seg.copy(deep=True)[['PatientID', 'StudyInstanceUID', 'SeriesInstanceUID']]
df_patient = df_patient.drop_duplicates(subset=['PatientID', 'StudyInstanceUID', 'SeriesInstanceUID'])
df_patient.head()

PatientID_list = df_patient['PatientID'].values
StudyInstanceUID_list = df_patient['StudyInstanceUID'].values
SeriesInstanceUID_list = df_patient['SeriesInstanceUID'].values

# %%
# We add the gcs_url of the SEG file to this dataframe
gcs_url_seg = [os.path.join("gs://nlstseg_seg_and_sr/seg", f + "_SEG.dcm") for f in SeriesInstanceUID_list]
df_patient['gcs_url_seg'] = gcs_url_seg

# %%
len(df_patient)
# Out:
# 402

# %%
df_patient.head()
# Out:
#   PatientID                                   StudyInstanceUID  \
# 0    102736  1.2.840.113654.2.55.23485103792480070136869664...
# 2    120573  1.2.840.113654.2.55.60312645929603274507035783...
# 4    114248  1.2.840.113654.2.55.14865377394025870860835319...
# 6    113623  1.2.840.113654.2.55.22482478647078478355738832...
# 9    102537  1.2.840.113654.2.55.17698629574705452327296269...
#
#                                    SeriesInstanceUID  \
# 0  1.2.840.113654.2.55.77451854363369829573866150...
# 2  1.2.840.113654.2.55.32568708984853805318844556...
# 4  1.2.840.113654.2.55.12363323410784959119051552...
# 6  1.2.840.113654.2.55.17412435624899643050868386...
# 9  1.2.840.113654.2.55.17923185272132498184218647...
#
#                                          gcs_url_seg
# 0  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...
# 2  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...
# 4  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...
# 6  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...
# 9  gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.5...

# %%
# Download all the SEG files from the bucket for this list of series
seg_directory_bucket = "gs://nlstseg_seg_and_sr/seg"
seg_directory = "/content/seg"
if not os.path.isdir(seg_directory):
  os.mkdir(seg_directory)

# Create the text file to hold gsc_url
gcsurl_temp = df_patient["gcs_url_seg"]
gs_file_path = "gcs_paths.txt"
gcsurl_temp.to_csv(gs_file_path, header = False, index = False)

# !cat manifest.txt | gsutil -m cp -I .
# !cat gcs_paths.txt | gsutil -m cp -I $seg_directory
# Out:
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.77451854363369829573866150401935945777_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.3256870898485380531884455642265281171_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.123633234107849591190515522342469572867_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.174124356248996430508683867152648202173_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.179231852721324981842186473145321629778_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.182315093935481624682845229846809224632_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.158364186499334911697140176182635356136_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.38995485391900019876570761037952058249_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.333959368472243697306539144681085718022_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.135314423026715332810549867523376949749_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.205688193328322143786287645000299423375_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.80716887202718212912842134755481869828_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.131554014629074879725055125050225541536_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.32005491511751878907785232875733365323_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.204642191063326653170110007925732322027_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.337246498180183225505847852854636608611_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.144931383235854544235300790173_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.315936508105811304217698316302_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.326325246098191006027436420248_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.280645634420542648203290402777_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.187916168052143707748361859868934457191_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.213758672215327638179929291394926351146_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.11540944481901480924019938119296989447_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.202078761136036749161107553563389075803_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.198981735234109140872055852899557001028_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.265811533156606495950473119879580087587_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.232459064054253624772250053551839110752_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.81809749276986725587053210360651375677_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.312030893713712616757213977244096850146_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.175141405312830297022101030636287677783_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.14382674871619950799472325766084940706_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.98213040593693505162579915860735971212_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.144340766508502271029060627876045251510_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.158466220092524136496371772149930312991_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.320120460469255723293391943100324223254_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.926070962577152530576648493883_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.192525281608175837322789780307_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.328556977712236541287818198607_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.175817836062435210980057971444_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.339956946238032705972603308685416663482_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.195687615519561194715245096282403100906_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.84447557825092715693249482357262634235_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.118099385827111603176263458990659555444_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17658683864590510336787393836845418990_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.174639415508620935145028282277042780072_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.173358788996277876607007025414753328199_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.49839034697406949726005641395881606917_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.119018409217210401675509551230628494456_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.103164989352592098929741164632137395127_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.123800934642743115448994694971021310180_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.211850622695004227027857089558221518940_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.324222466647716155625000469242011339484_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.217802425509966403654479669956553198048_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.174815865605540072126627846390000187679_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.20260464352090956925306653731131974215_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.36720472879967990193144980615763182705_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.280652015329571311885707163360976739271_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.273747268704781042450389888241893976150_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.194100962498581744629324365001643858987_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.315901155485141710568107208522744119403_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.252790578163294500394363956440600203102_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.33050419981657925174979113934207159380_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.225893401562023672707560220661212937130_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.94518475546509771370984195173527757543_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.40305727010684967538867737864782266115_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.262564043997006039201662725545109911310_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.219933463752955637040480130954321726544_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.80557134350152339289139946609720557730_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.171025045496816499829908809908233964832_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.298012365445252708668937282753163582528_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.627929135391099950342760251760_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.650053797534074365337114411297_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.309253156651422584290397669325778568792_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.194354562095023448671282511635920859408_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.125598864949686036444273683439_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.144965022893191407663386785886_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.222261554379030963094799371916_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.621779377940751615087414392379_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.297805958752394287945623151974_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.303195469219875859644940611845_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.990172827664001291939530751684_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.179068386711781741405062504446_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.239054227238294741410265568772_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.401862589013349125493694494808_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.227972196329718903717660021172_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.129921359485285227905335949620_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.291893030174859756508765761855_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.153924221910814877136808476968_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.244483413823778426481268994927175193345_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.151736094660966670123489964024716942063_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.14162314108578666423704822512735867871_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.16111750182367908886746912872049323704_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.112005050407705221921489268378715630967_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.237560930829175677728490591999091180420_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.162822187424066537685643792190649946297_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.294423248031318124872302490007395358486_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.87797263584059817420422842408163180099_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.83049458161444568535575942046508951670_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.219098170002792961663484151881908979793_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.9891152751121069541185696923049096885_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.105508597935357050120573060055759818144_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.122971168483213702501252817806311025669_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.336730487527427251909409858213101119123_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.27330557752167762437527417985475091283_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.19197457608385641817198995765620969796_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.65288672934924396656060784644935830286_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.128811497746561400357955147775811342417_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.292417379275620347083895524863594772869_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.46266614602271282854322228698604669142_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.32496072008315898589920724459377473768_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.240210190823923620084664786958280422251_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.73154804189607782205657648688778767637_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.145741332869175592333239317825408351493_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.294983438880810048468659241971163483684_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.215926225076041414333338084890561111589_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.181630417793454766365488688006739846292_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.285908287366994103953414791693711341798_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.235141650950874282078131410152740797115_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.161305680565057257280628853676270391350_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.131677473662446160187267284953_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.183906244161753983993523861544_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.297665473749571577022552863644_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.328603427551231924197632135930_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.209285809611899739404379081173_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.326652722868765760512456527653_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.103043553043570071841168962847_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89033549933870375562545956359273139713_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.108736834907802190085065988996748090438_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.187488516158751447197073642392431374839_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.124449392974478871131429591436196671404_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.190772681372305047985301430611863350467_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.239065060077110334990368225803561003591_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.111450695377676523221372569079048491205_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.196622501102736074294090844425373743728_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.115175509770416319783772085325746597427_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.72429733128858640522374348303342889232_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.41091495790610194459724135577096464690_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.135968128742262057179054957067531073282_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.272450963487547376605393207916814195103_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.310609767809678441522963921292898109470_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.138166888591278777644190888301898501250_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.302248287903390299854039275975618817746_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.10212803674068251180698456742623207615_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.203089102823995295943633338597998288409_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.331946355905898862508372677989078330393_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.174138771322323571478875114343_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.255298045766679977296292618717619397173_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.169309936075332267797085665689677792004_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.261245792492590026839419370097967940966_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.339835645798758446691532724163_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.288574468796501890471931832631663421295_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.137284376304168395503445289171119065795_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.55905915368746417680608580988846234578_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.261920674960844087932144874292577892490_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.275710763012564703750919408555_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.133458457674502234162562970110_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.164586013035960730340611327787_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.112251960264319977744085244552_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.572219882663875211157944328868_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.630724833692378622177598798421_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.263827526097824451486081334589_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.138475685444403243712417929667_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.186718476017960288836619454001_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.333884524290327041910062800676697116570_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.60284554997549760208978021192752401714_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.322184916910148879927506802612139491767_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.291361586149710617044794254619653059093_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.125403043383466225171814830534052775879_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.116178619022139425999957920748644970996_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.238814541182280662161737112338918718341_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.207655924093883599445157375675238622055_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.289109210467811685626758090334149277572_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.157089410086487452104998883963678895145_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.729684157914255333591022131690_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.262292750379305468195976945717214632568_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.318323353513155615753961713305147161871_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.292479773624816414906106118083545163299_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.199280757164420714744169293221_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.274864899329458805359494586539_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.211572945097332183618302638652_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.216648624768018621300629367171_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.123262946416173131342778997641_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.273496443861029715343178669949_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.225506400203554305763827757238_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.224675142672761997512683643121_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.148800903815565314876573314988_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.115028254815852577487486355210417616410_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.225338428432733808973910426933_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.198678801664998611593159046987_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.323067664901890164304171820617478007365_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.62102832281866128335133952467331151018_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.201655506612925010288892835508800465315_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.265538721267645811445152681366443319503_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.297475359465669712309938774091708798816_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.119278381949136177284416234961643134266_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.198219587826015290649042601161_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.236423142679897697811855204133432442977_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.48603091694994608738318392223018348755_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.207640369878214224021885933204737576317_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.128362675825191379264782186218670385164_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.187625177555389677985422106104_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.85571577504442452992028641567857501834_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.206445619027777579146291436718278090156_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.312892052066020486212291113477170324390_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.244639088722574373221242820202_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.157204904209311171860286597352_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.127084246870040525887479880429_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.979854419582121445438454522940_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.172726594946631932238874333328_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.163631608039008231432551652759_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.244889788704777117265791693743_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.264823538108475401141178460625066576318_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.296339628639169155708773470329671748912_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.67095101227495808685302586770473894957_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89728807369105801595655166766945676208_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.14059028299195631370217959879698398394_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.232897582370228023625896718890064986745_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.65769548478962835586696130973853762477_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.202119798672919693443240353002_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.323804676332963457174235140303454945005_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.145745567373257852212520912375_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.231220162980458064663806103389419026678_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.98360851027786845429916202030579152093_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.1541837184580403203301129857398567723_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.64243829174890265599006202544885558888_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.85329497298127431588006646990027262565_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.302609055429861799803994589436_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.115306161827798335724668734142_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.247714574186092243007275105443_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.335068937133704782371543277892_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.155830797336710173530941808595_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.252746870598745190555002158435555893859_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.294795888751210912516507666864500510900_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.334561430487539693988609745570841610261_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.214483182570512319377495527619089952642_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.68648218892121690706317410635829132003_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.403437758939997784849726820932_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.257416692801824567109770633434577562863_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.758651454056241277004038704552_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17008868569894927008450364376626360407_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.332576596933483367821758555164986814820_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.106004492444389108941417962052_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.130899157122224000055388738766_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.194978440150538663191132330353_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.143578662029406444612978007728_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.161264160024979199783419898154_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.118722452529394350711166589345_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.133810826757692085945762413768_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.311135448859317568772411569963288214388_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89807759908895591032049335991091731003_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.20522329972429455898321727187899724639_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89477011945581920116417298062890129546_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.314395911906052434902081644014516651984_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.164768804662547412701807688620_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.165884453203631061279010869629665746850_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.261574503797213869314392805762561343844_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.170115213539867939035437973056423075675_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17879920116288438977407432295523363002_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.63621237136724691963349850896317513699_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.63873242866827151558814889186531561452_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.89534960921624589282242592246163391311_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.281122741744238701551394451058782960222_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.135083646840972124662519033272893593787_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.619979304741157495229660017147_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.732617958380743426518581294837_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.321015447560879747152307811899265404393_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.96030936677299998289459301371355143208_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.299569302054927466999467983745_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.330420120433623992136851296394350684412_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.200932748333982227270105712503240293455_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.211327659440826290111901768213020906899_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.102679371468953163285569140890061441420_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.30276220214859282848718508697843613549_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.342418580706193998489061702827_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.256819939386902184239905556344723042029_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.202590990749233587270867529690119914374_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.223908149059930082550276878780455910207_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.207780613005490675500630966674_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.139132008311013694893031394896_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.274906584527642775644898336045_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.124662392740618336534191185780_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.112918986098180666980407474761214092582_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.169697003742573435409614923241347675640_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.18887628356060209734659781975646207647_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.140683453079065910695641432774813371083_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.162237089181970393467571471916_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.164750762258986107157881513300_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17220587240744170390288046904619698262_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.99981418632728007269752227847647500242_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.152351375083351137728883443485571695816_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.302409961332202189020256932391_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.821126619905759469865221670961_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.118240946395420474084011752812684423_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.129862789291463473130925568643344102761_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.274162140146233248111505261965574389069_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.46585009632538178829747577506479558322_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.248871178457179134133268428984990824357_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.231164885435494609343364648624058240444_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.802863658154164773047723219988_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.265076645294278420451491835992_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.153809938501803691882470179510604553143_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.276026819340563014906269522292_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.652542111531875496786085581001_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.711080093533188530839761726262_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.243584105004498617479171114963549864998_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.176071054683304110719613713146_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.163329702376772650635014222425_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.168559985013271056832798296931_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.243510052221089905476547647221_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.300496294376345950127114445834693790599_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.65659509888424322769427058438403064906_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.300162360460384875273646744692_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.240324207329350237274075536816_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.101314786969371795881789869088_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.81136962133262551156371928517766508555_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.238944838267171045713423118512022976877_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.972046923789567546322049002825_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.333811371558544670788812029369_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.114246821382240569611380795975517495817_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.22084245517968704647300402362399724489_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.55024213553689027610844746016919431304_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.55249935124047036645194998679497712331_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.79585603887413976622151425154743589691_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.133386609493277240203927332124127709601_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.234870527508599761640999671632707483702_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.226720282857983435615951947960_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.933841618640476833036494357619_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.282605138934435721988472315082_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.289613708626719952213368966039473341125_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.232991909979178037566082101940837619916_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.278537402659263177052326157620432088005_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.211912645826213218933934057307_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.291681719373684904720555718424_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.284978732490496848337467051474_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.303640943191823703361709653866526987877_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.209806477987078981088659965402559013159_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.317421001614200749620554087852_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.13335422647841201767208337101314418669_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.232131513785165026353474411362_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.263367954198156875547874810827609051599_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.113040386178547843571271236478024341696_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.291884765038938171737345289866_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.217768437685736767355231176035_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.248367220149114779001236080527_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.117168587881036721196334662566_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.180073756539777283491523882175_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.145215505102406333449483782713_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.176175057280389142500002693117_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.118365698813953167004356850681_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.302533635268177260202698156939540188162_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.78299330143623946343061044933747516_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.175674334851122081937703890069307803316_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.136132521671327053038928327413_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.315815227684601141210995143893765985256_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.449796649149718023106515279959_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.552954451305841457246485097814_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.38331112054215767893080935276683387701_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.170001881918406048131014011358_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.336832610089461934819661898582_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.181715871926844141208177392303_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.115451276425386762335739651324_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.130711389735203660002446393754174369152_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.128719895339498507728437515897_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.224817689169801013577098072503701293247_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.163513449124025050135426427567_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.940569451464186902108955404481_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.216419520616220970553194986094193028074_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.251522632416638635859677462723_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.322861777944986297549227585914529686199_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.200956373299047913742718734139_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.222684182749361389519417245884_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.195129470296841381925530422059553789327_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.102236556545478157092621557341658509914_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.246434579828531057425449543998861587365_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.38380760938863740334622103795226994737_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.174014234720705051674481406448_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.182434043811696504163378688408_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.288726058103780350347376743042404078910_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.81192991204494217085986885579563426789_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.102595981262437924743384555490348997068_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.676754769558561163655830587788_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.67851195947766274164353383578546290143_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.58920416584809699905140578786295322821_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.211693205194678397362913455586_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.241924049353992159785903857377772231263_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.674424600608887623087401566792_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.17946222853752357522036394138531044474_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.320594890074080794313231338281406181426_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.113963576659208997922505947759_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.317659298387497834095252537572_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.277152651983810061753947249581_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.257830882183445545540953609532_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.131131828321708464413596959557_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.274095880606342862580083739420627901741_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.279100853054623203238704107156162119159_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.39516155940744949926070642539192360812_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.518652745898860177551735611820_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.785517485814092310381399550467_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.197537342578509830000233537889459327883_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.236581477720516135789038198297_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.184034787304891046495973007321_SEG.dcm...
# Copying gs://nlstseg_seg_and_sr/seg/1.3.6.1.4.1.14519.5.2.1.7009.9004.269922574105136237935136769376_SEG.dcm...
# / [402/402 files][163.4 MiB/163.4 MiB] 100% Done  14.1 MiB/s ETA 00:00:00
# Operation completed over 402 objects/163.4 MiB.

# %%
def tumor_fraction_in_box(mask, bbox):
  """
  mask: 2D numpy array (0/1 or bool) for tumor
  bbox: (xmin, ymin, xmax, ymax) in pixel coordinates
        (x = cols, y = rows)
  Returns: fraction of tumor voxels inside the box
  """
  xmin, ymin, xmax, ymax = bbox

  # clip to image bounds
  ymin = max(0, ymin); ymax = min(mask.shape[0], ymax)
  xmin = max(0, xmin); xmax = min(mask.shape[1], xmax)

  # box mask
  box_mask = np.zeros_like(mask, dtype=bool)
  box_mask[ymin:ymax, xmin:xmax] = True

  # intersection
  tumor_inside = np.logical_and(mask.astype(bool), box_mask)
  fraction = tumor_inside.sum() / mask.sum() if mask.sum() > 0 else np.nan

  return fraction

# %%
df_overlap_all = pd.DataFrame()
print('Num patients: ' + str(len(PatientID_list)))

### Over each patient ###
for index, patient in enumerate(PatientID_list,1):
  print('*** On index: ' + str(index) + ' ***')
  print(patient)
  StudyInstanceUIDs = list(set(df_patient[df_patient['PatientID']==patient]['StudyInstanceUID'].values))

  ### Over each study ###
  for study in StudyInstanceUIDs:
    series = list(set(df_patient[df_patient['StudyInstanceUID']==study]['SeriesInstanceUID'].values))

    ### Over each series ###
    for series in series:

      ### Get the appropriate SEG file ###
      seg_filename = os.path.join("/content/seg", series + "_SEG.dcm")

      ### Get the referencedSOPInstanceUIDs and the mask indices ###
      # We know which slices have an overlap - by the referencedSOPInstanceUID
      # Now we need to get the pixel data for those slices.
      seg = pydicom.dcmread(seg_filename)
      # Get the pixel array data
      mask_data = seg.pixel_array
      # Need to get the per frame function groups - to know the referencedSOPInstanceUIDs
      pffg = seg.PerFrameFunctionalGroupsSequence
      num_slices_in_seg = len(pffg)
      print('num_slices_in_seg: ' + str(num_slices_in_seg))
      pffg_sop_list = []
      error_der_image_sequence = 0
      for n in range(0,num_slices_in_seg):
        try:
          sop = pffg[n].DerivationImageSequence[0].SourceImageSequence[0].ReferencedSOPInstanceUID
        except:
          print('ERROR: cannot access derivation image sequence')
          error_der_image_sequence = -1
          continue
        pffg_sop_list.append(sop)
      # Now create a dataframe with the SOPInstanceUID and the slice index into mask
      df_seg = pd.DataFrame()
      df_seg['SOPInstanceUID'] = pffg_sop_list
      df_seg['mask_slice'] = np.arange(0,len(pffg_sop_list))

      ### Now get the referencedSOPInstanceUID for the sybil bbox
      df_sybil_bbox_temp = df_sybil_bbox[df_sybil_bbox['SeriesInstanceUID']==series]

      ### Now only keep the referencedSOPInstanceUIDs that overlap ###
      df_overlap = df_seg.merge(df_sybil_bbox, left_on='SOPInstanceUID', right_on='ReferencedSOPInstanceUID')
      df_overlap = df_overlap.drop(columns=['SOPInstanceUID_y'])
      df_overlap = df_overlap.rename(columns={'SOPInstanceUID_x':'SOPInstanceUID'})

      ### For each slice, calculate the overlap ###
      SOPInstanceUID_list = df_overlap['ReferencedSOPInstanceUID'].values
      mask_slice_list = df_overlap['mask_slice'].values

      metric_list = []
      if (error_der_image_sequence==0):
        for SOPInstanceUID,mask_slice in zip(SOPInstanceUID_list,mask_slice_list):
          df_temp = df_overlap[df_overlap['ReferencedSOPInstanceUID']==SOPInstanceUID]
          x0 = df_temp['x0'].values[0]; y0 = df_temp['y0'].values[0]
          x1 = df_temp['x1'].values[0]; y1 = df_temp['y1'].values[0]
          x2 = df_temp['x2'].values[0]; y2 = df_temp['y2'].values[0]
          x3 = df_temp['x3'].values[0]; y3 = df_temp['y3'].values[0]
          width = x1 - x0 # can change later
          height = y2 - y1 # can change later
          xmin = x0 # can change later
          ymin = y0 # can change later
          xmax = xmin + width
          ymax = ymin + height
          bbox = [np.floor(xmin).astype(np.int16),
                  np.floor(ymin).astype(np.int16),
                  np.ceil(xmax).astype(np.int16),
                  np.ceil(ymax).astype(np.int16)]
          metric = tumor_fraction_in_box(mask_data[mask_slice,:,:], bbox)
          metric_list.append(metric)
        # Add to dataframe
        df_overlap['overlap_metric'] = metric_list

  # Add to overall dataframe
  if (error_der_image_sequence==0):
    df_overlap_all = pd.concat([df_overlap_all, df_overlap], axis=0)



# Add the ohif url
viewer_url = ["https://viewers-sandbox-gha-testing.web.app/viewer/?StudyInstanceUIDs=" + f + "&gcp=projects/idc-external-018/locations/us-central1/datasets/sybil_and_nlstseg/dicomStores/sybil_and_nlstseg" for f in df_overlap_all['StudyInstanceUID'].values]
df_overlap_all['viewer_url'] = viewer_url

# Save
df_overlap_all.to_csv("/content/sybil_and_nlstseg_overlap.csv")
# Out:
# Num patients: 402
# *** On index: 1 ***
# 102736
# num_slices_in_seg: 2
# *** On index: 2 ***
# 120573
# num_slices_in_seg: 2
# *** On index: 3 ***
# 114248
# num_slices_in_seg: 2
# *** On index: 4 ***
# 113623
# num_slices_in_seg: 3
# *** On index: 5 ***
# 102537
# num_slices_in_seg: 3
# *** On index: 6 ***
# 102267
# num_slices_in_seg: 3
# *** On index: 7 ***
# 134009
# num_slices_in_seg: 3
# *** On index: 8 ***
# 100242
# num_slices_in_seg: 3
# *** On index: 9 ***
# 124533
# num_slices_in_seg: 3
# *** On index: 10 ***
# 129155
# num_slices_in_seg: 3
# *** On index: 11 ***
# 124998
# num_slices_in_seg: 3
# *** On index: 12 ***
# 107434
# num_slices_in_seg: 3
# *** On index: 13 ***
# 108352
# num_slices_in_seg: 3
# *** On index: 14 ***
# 110716
# num_slices_in_seg: 3
# *** On index: 15 ***
# 106432
# num_slices_in_seg: 3
# *** On index: 16 ***
# 106000
# num_slices_in_seg: 3
# *** On index: 17 ***
# 206732
# num_slices_in_seg: 3
# *** On index: 18 ***
# 216940
# num_slices_in_seg: 3
# *** On index: 19 ***
# 206687
# num_slices_in_seg: 3
# *** On index: 20 ***
# 205687
# num_slices_in_seg: 3
# *** On index: 21 ***
# 118672
# num_slices_in_seg: 3
# *** On index: 22 ***
# 130133
# num_slices_in_seg: 4
# *** On index: 23 ***
# 102660
# num_slices_in_seg: 4
# *** On index: 24 ***
# 133201
# num_slices_in_seg: 4
# *** On index: 25 ***
# 117612
# num_slices_in_seg: 4
# *** On index: 26 ***
# 101692
# num_slices_in_seg: 4
# *** On index: 27 ***
# 107328
# num_slices_in_seg: 4
# *** On index: 28 ***
# 124486
# num_slices_in_seg: 4
# *** On index: 29 ***
# 123072
# num_slices_in_seg: 4
# *** On index: 30 ***
# 104208
# num_slices_in_seg: 4
# *** On index: 31 ***
# 105142
# num_slices_in_seg: 4
# *** On index: 32 ***
# 121169
# num_slices_in_seg: 4
# *** On index: 33 ***
# 126977
# num_slices_in_seg: 4
# *** On index: 34 ***
# 114378
# num_slices_in_seg: 4
# *** On index: 35 ***
# 131542
# num_slices_in_seg: 4
# *** On index: 36 ***
# 216238
# num_slices_in_seg: 4
# *** On index: 37 ***
# 200066
# num_slices_in_seg: 4
# *** On index: 38 ***
# 217121
# num_slices_in_seg: 4
# *** On index: 39 ***
# 200683
# num_slices_in_seg: 4
# *** On index: 40 ***
# 120969
# num_slices_in_seg: 5
# *** On index: 41 ***
# 130706
# num_slices_in_seg: 5
# *** On index: 42 ***
# 131156
# num_slices_in_seg: 5
# *** On index: 43 ***
# 133811
# num_slices_in_seg: 5
# *** On index: 44 ***
# 119924
# num_slices_in_seg: 5
# *** On index: 45 ***
# 124261
# num_slices_in_seg: 5
# *** On index: 46 ***
# 106204
# num_slices_in_seg: 5
# *** On index: 47 ***
# 100913
# num_slices_in_seg: 5
# *** On index: 48 ***
# 102746
# num_slices_in_seg: 5
# *** On index: 49 ***
# 110061
# num_slices_in_seg: 5
# *** On index: 50 ***
# 121794
# num_slices_in_seg: 5
# *** On index: 51 ***
# 104182
# num_slices_in_seg: 5
# *** On index: 52 ***
# 109573
# num_slices_in_seg: 5
# *** On index: 53 ***
# 132313
# num_slices_in_seg: 5
# *** On index: 54 ***
# 101068
# num_slices_in_seg: 5
# *** On index: 55 ***
# 123891
# num_slices_in_seg: 5
# *** On index: 56 ***
# 130624
# num_slices_in_seg: 5
# *** On index: 57 ***
# 106926
# num_slices_in_seg: 5
# *** On index: 58 ***
# 112258
# num_slices_in_seg: 5
# *** On index: 59 ***
# 104063
# num_slices_in_seg: 5
# *** On index: 60 ***
# 110356
# num_slices_in_seg: 5
# *** On index: 61 ***
# 101066
# num_slices_in_seg: 5
# *** On index: 62 ***
# 125727
# num_slices_in_seg: 5
# *** On index: 63 ***
# 110253
# num_slices_in_seg: 5
# *** On index: 64 ***
# 126520
# num_slices_in_seg: 5
# *** On index: 65 ***
# 112073
# num_slices_in_seg: 5
# *** On index: 66 ***
# 107610
# num_slices_in_seg: 5
# *** On index: 67 ***
# 112893
# num_slices_in_seg: 5
# *** On index: 68 ***
# 122866
# num_slices_in_seg: 5
# *** On index: 69 ***
# 115524
# num_slices_in_seg: 5
# *** On index: 70 ***
# 124190
# num_slices_in_seg: 5
# *** On index: 71 ***
# 210581
# num_slices_in_seg: 5
# *** On index: 72 ***
# 203861
# num_slices_in_seg: 5
# *** On index: 73 ***
# 126792
# num_slices_in_seg: 5
# *** On index: 74 ***
# 130315
# num_slices_in_seg: 5
# *** On index: 75 ***
# 217482
# num_slices_in_seg: 5
# *** On index: 76 ***
# 211494
# num_slices_in_seg: 5
# *** On index: 77 ***
# 202822
# num_slices_in_seg: 5
# *** On index: 78 ***
# 202165
# num_slices_in_seg: 5
# *** On index: 79 ***
# 202268
# num_slices_in_seg: 5
# *** On index: 80 ***
# 207391
# num_slices_in_seg: 5
# *** On index: 81 ***
# 208589
# num_slices_in_seg: 5
# *** On index: 82 ***
# 208735
# num_slices_in_seg: 5
# *** On index: 83 ***
# 204870
# num_slices_in_seg: 5
# *** On index: 84 ***
# 211707
# num_slices_in_seg: 5
# *** On index: 85 ***
# 200056
# num_slices_in_seg: 5
# *** On index: 86 ***
# 200969
# num_slices_in_seg: 5
# *** On index: 87 ***
# 207691
# num_slices_in_seg: 5
# *** On index: 88 ***
# 204067
# num_slices_in_seg: 5
# *** On index: 89 ***
# 133076
# num_slices_in_seg: 6
# ERROR: cannot access derivation image sequence
# *** On index: 90 ***
# 123944
# num_slices_in_seg: 6
# *** On index: 91 ***
# 105974
# num_slices_in_seg: 6
# *** On index: 92 ***
# 103665
# num_slices_in_seg: 6
# *** On index: 93 ***
# 128944
# num_slices_in_seg: 6
# *** On index: 94 ***
# 103507
# num_slices_in_seg: 6
# *** On index: 95 ***
# 103344
# num_slices_in_seg: 6
# *** On index: 96 ***
# 131174
# num_slices_in_seg: 6
# *** On index: 97 ***
# 134491
# num_slices_in_seg: 6
# *** On index: 98 ***
# 116289
# num_slices_in_seg: 6
# *** On index: 99 ***
# 129627
# num_slices_in_seg: 6
# *** On index: 100 ***
# 107058
# num_slices_in_seg: 6
# *** On index: 101 ***
# 127992
# num_slices_in_seg: 6
# *** On index: 102 ***
# 119358
# num_slices_in_seg: 6
# *** On index: 103 ***
# 114746
# num_slices_in_seg: 6
# *** On index: 104 ***
# 102161
# num_slices_in_seg: 6
# *** On index: 105 ***
# 109532
# num_slices_in_seg: 6
# *** On index: 106 ***
# 107133
# num_slices_in_seg: 6
# *** On index: 107 ***
# 130975
# num_slices_in_seg: 6
# *** On index: 108 ***
# 102581
# num_slices_in_seg: 6
# *** On index: 109 ***
# 128940
# num_slices_in_seg: 6
# *** On index: 110 ***
# 122117
# num_slices_in_seg: 6
# *** On index: 111 ***
# 111454
# num_slices_in_seg: 6
# *** On index: 112 ***
# 117820
# num_slices_in_seg: 6
# *** On index: 113 ***
# 133279
# num_slices_in_seg: 6
# *** On index: 114 ***
# 103232
# num_slices_in_seg: 6
# *** On index: 115 ***
# 106971
# num_slices_in_seg: 6
# *** On index: 116 ***
# 131306
# num_slices_in_seg: 6
# *** On index: 117 ***
# 123521
# num_slices_in_seg: 6
# *** On index: 118 ***
# 121893
# num_slices_in_seg: 6
# *** On index: 119 ***
# 133321
# num_slices_in_seg: 6
# *** On index: 120 ***
# 210371
# num_slices_in_seg: 6
# *** On index: 121 ***
# 213630
# num_slices_in_seg: 6
# *** On index: 122 ***
# 218307
# num_slices_in_seg: 6
# *** On index: 123 ***
# 209140
# num_slices_in_seg: 6
# *** On index: 124 ***
# 204473
# num_slices_in_seg: 6
# *** On index: 125 ***
# 205714
# num_slices_in_seg: 6
# *** On index: 126 ***
# 209512
# num_slices_in_seg: 6
# *** On index: 127 ***
# 119474
# num_slices_in_seg: 6
# *** On index: 128 ***
# 134408
# num_slices_in_seg: 7
# *** On index: 129 ***
# 110071
# num_slices_in_seg: 7
# *** On index: 130 ***
# 107791
# num_slices_in_seg: 7
# *** On index: 131 ***
# 133786
# num_slices_in_seg: 7
# *** On index: 132 ***
# 134371
# num_slices_in_seg: 7
# *** On index: 133 ***
# 129511
# num_slices_in_seg: 7
# *** On index: 134 ***
# 108766
# num_slices_in_seg: 7
# *** On index: 135 ***
# 116747
# num_slices_in_seg: 7
# *** On index: 136 ***
# 118323
# num_slices_in_seg: 7
# *** On index: 137 ***
# 131423
# num_slices_in_seg: 7
# *** On index: 138 ***
# 119597
# num_slices_in_seg: 7
# *** On index: 139 ***
# 101192
# num_slices_in_seg: 7
# *** On index: 140 ***
# 100158
# num_slices_in_seg: 7
# *** On index: 141 ***
# 111355
# num_slices_in_seg: 7
# *** On index: 142 ***
# 122364
# num_slices_in_seg: 7
# *** On index: 143 ***
# 126955
# num_slices_in_seg: 7
# *** On index: 144 ***
# 114311
# num_slices_in_seg: 7
# *** On index: 145 ***
# 105340
# num_slices_in_seg: 7
# *** On index: 146 ***
# 214822
# num_slices_in_seg: 7
# *** On index: 147 ***
# 100703
# num_slices_in_seg: 7
# *** On index: 148 ***
# 106364
# num_slices_in_seg: 7
# *** On index: 149 ***
# 127890
# num_slices_in_seg: 7
# *** On index: 150 ***
# 208446
# num_slices_in_seg: 7
# *** On index: 151 ***
# 131486
# num_slices_in_seg: 7
# *** On index: 152 ***
# 127302
# num_slices_in_seg: 7
# *** On index: 153 ***
# 132047
# num_slices_in_seg: 7
# *** On index: 154 ***
# 106498
# num_slices_in_seg: 7
# *** On index: 155 ***
# 212293
# num_slices_in_seg: 7
# *** On index: 156 ***
# 209874
# num_slices_in_seg: 7
# *** On index: 157 ***
# 209865
# num_slices_in_seg: 7
# *** On index: 158 ***
# 214975
# num_slices_in_seg: 7
# *** On index: 159 ***
# 217951
# num_slices_in_seg: 7
# *** On index: 160 ***
# 209119
# num_slices_in_seg: 7
# *** On index: 161 ***
# 207830
# num_slices_in_seg: 7
# *** On index: 162 ***
# 201726
# num_slices_in_seg: 7
# *** On index: 163 ***
# 200397
# num_slices_in_seg: 7
# *** On index: 164 ***
# 113952
# num_slices_in_seg: 8
# *** On index: 165 ***
# 107521
# num_slices_in_seg: 8
# *** On index: 166 ***
# 129285
# num_slices_in_seg: 8
# *** On index: 167 ***
# 106753
# num_slices_in_seg: 8
# *** On index: 168 ***
# 118664
# num_slices_in_seg: 8
# *** On index: 169 ***
# 104564
# num_slices_in_seg: 8
# *** On index: 170 ***
# 132227
# num_slices_in_seg: 8
# *** On index: 171 ***
# 123066
# num_slices_in_seg: 8
# *** On index: 172 ***
# 116137
# num_slices_in_seg: 8
# *** On index: 173 ***
# 100147
# num_slices_in_seg: 8
# *** On index: 174 ***
# 212202
# num_slices_in_seg: 8
# *** On index: 175 ***
# 130467
# num_slices_in_seg: 8
# *** On index: 176 ***
# 130655
# num_slices_in_seg: 8
# *** On index: 177 ***
# 126698
# num_slices_in_seg: 8
# *** On index: 178 ***
# 218013
# num_slices_in_seg: 8
# *** On index: 179 ***
# 212222
# num_slices_in_seg: 8
# *** On index: 180 ***
# 214923
# num_slices_in_seg: 8
# *** On index: 181 ***
# 203791
# num_slices_in_seg: 8
# *** On index: 182 ***
# 215151
# num_slices_in_seg: 8
# *** On index: 183 ***
# 201674
# num_slices_in_seg: 8
# *** On index: 184 ***
# 202611
# num_slices_in_seg: 8
# *** On index: 185 ***
# 206564
# num_slices_in_seg: 8
# *** On index: 186 ***
# 210090
# num_slices_in_seg: 8
# *** On index: 187 ***
# 102388
# num_slices_in_seg: 8
# *** On index: 188 ***
# 206737
# num_slices_in_seg: 8
# *** On index: 189 ***
# 213734
# num_slices_in_seg: 8
# *** On index: 190 ***
# 111243
# num_slices_in_seg: 9
# *** On index: 191 ***
# 112235
# num_slices_in_seg: 9
# *** On index: 192 ***
# 119839
# num_slices_in_seg: 9
# *** On index: 193 ***
# 118560
# num_slices_in_seg: 9
# *** On index: 194 ***
# 121004
# num_slices_in_seg: 9
# *** On index: 195 ***
# 102658
# num_slices_in_seg: 9
# *** On index: 196 ***
# 204878
# num_slices_in_seg: 9
# *** On index: 197 ***
# 105562
# num_slices_in_seg: 9
# *** On index: 198 ***
# 121469
# num_slices_in_seg: 9
# *** On index: 199 ***
# 120954
# num_slices_in_seg: 9
# *** On index: 200 ***
# 120708
# num_slices_in_seg: 9
# *** On index: 201 ***
# 214640
# num_slices_in_seg: 9
# *** On index: 202 ***
# 105352
# num_slices_in_seg: 9
# *** On index: 203 ***
# 107561
# num_slices_in_seg: 9
# *** On index: 204 ***
# 104363
# num_slices_in_seg: 9
# *** On index: 205 ***
# 207786
# num_slices_in_seg: 9
# *** On index: 206 ***
# 213860
# num_slices_in_seg: 9
# *** On index: 207 ***
# 207869
# num_slices_in_seg: 9
# *** On index: 208 ***
# 213544
# num_slices_in_seg: 9
# *** On index: 209 ***
# 201979
# num_slices_in_seg: 9
# *** On index: 210 ***
# 205046
# num_slices_in_seg: 9
# *** On index: 211 ***
# 206354
# num_slices_in_seg: 9
# *** On index: 212 ***
# 100658
# num_slices_in_seg: 9
# *** On index: 213 ***
# 128651
# num_slices_in_seg: 10
# *** On index: 214 ***
# 104168
# num_slices_in_seg: 10
# *** On index: 215 ***
# 126999
# num_slices_in_seg: 10
# *** On index: 216 ***
# 124864
# num_slices_in_seg: 10
# *** On index: 217 ***
# 102266
# num_slices_in_seg: 10
# *** On index: 218 ***
# 129553
# num_slices_in_seg: 10
# *** On index: 219 ***
# 207347
# num_slices_in_seg: 10
# *** On index: 220 ***
# 100570
# num_slices_in_seg: 10
# *** On index: 221 ***
# 209184
# num_slices_in_seg: 10
# *** On index: 222 ***
# 107682
# num_slices_in_seg: 10
# *** On index: 223 ***
# 101834
# num_slices_in_seg: 10
# *** On index: 224 ***
# 103621
# num_slices_in_seg: 10
# *** On index: 225 ***
# 109616
# num_slices_in_seg: 10
# *** On index: 226 ***
# 127923
# num_slices_in_seg: 10
# *** On index: 227 ***
# 208944
# num_slices_in_seg: 10
# *** On index: 228 ***
# 200674
# num_slices_in_seg: 10
# *** On index: 229 ***
# 214553
# num_slices_in_seg: 10
# *** On index: 230 ***
# 202976
# num_slices_in_seg: 10
# *** On index: 231 ***
# 217877
# num_slices_in_seg: 10
# *** On index: 232 ***
# 112289
# num_slices_in_seg: 10
# *** On index: 233 ***
# 108245
# num_slices_in_seg: 11
# *** On index: 234 ***
# 116798
# num_slices_in_seg: 11
# *** On index: 235 ***
# 101287
# num_slices_in_seg: 11
# *** On index: 236 ***
# 117502
# num_slices_in_seg: 11
# *** On index: 237 ***
# 211893
# num_slices_in_seg: 11
# *** On index: 238 ***
# 115571
# num_slices_in_seg: 11
# *** On index: 239 ***
# 201641
# num_slices_in_seg: 11
# *** On index: 240 ***
# 120570
# num_slices_in_seg: 11
# *** On index: 241 ***
# 103760
# num_slices_in_seg: 11
# *** On index: 242 ***
# 214419
# num_slices_in_seg: 11
# *** On index: 243 ***
# 211570
# num_slices_in_seg: 11
# *** On index: 244 ***
# 215101
# num_slices_in_seg: 11
# *** On index: 245 ***
# 203288
# num_slices_in_seg: 11
# *** On index: 246 ***
# 217203
# num_slices_in_seg: 11
# *** On index: 247 ***
# 205900
# num_slices_in_seg: 11
# *** On index: 248 ***
# 217438
# num_slices_in_seg: 11
# *** On index: 249 ***
# 117601
# num_slices_in_seg: 12
# *** On index: 250 ***
# 117799
# num_slices_in_seg: 12
# *** On index: 251 ***
# 132036
# num_slices_in_seg: 12
# *** On index: 252 ***
# 114541
# num_slices_in_seg: 12
# *** On index: 253 ***
# 104815
# num_slices_in_seg: 12
# *** On index: 254 ***
# 214907
# num_slices_in_seg: 12
# *** On index: 255 ***
# 121099
# num_slices_in_seg: 12
# *** On index: 256 ***
# 131657
# num_slices_in_seg: 12
# *** On index: 257 ***
# 110817
# num_slices_in_seg: 12
# *** On index: 258 ***
# 101387
# num_slices_in_seg: 12
# *** On index: 259 ***
# 106591
# num_slices_in_seg: 12
# *** On index: 260 ***
# 120701
# num_slices_in_seg: 12
# *** On index: 261 ***
# 130033
# num_slices_in_seg: 12
# *** On index: 262 ***
# 110196
# num_slices_in_seg: 12
# *** On index: 263 ***
# 113814
# num_slices_in_seg: 12
# *** On index: 264 ***
# 216978
# num_slices_in_seg: 12
# *** On index: 265 ***
# 205781
# num_slices_in_seg: 12
# *** On index: 266 ***
# 108611
# num_slices_in_seg: 12
# *** On index: 267 ***
# 118713
# num_slices_in_seg: 12
# *** On index: 268 ***
# 203581
# num_slices_in_seg: 12
# *** On index: 269 ***
# 104778
# num_slices_in_seg: 13
# *** On index: 270 ***
# 101397
# num_slices_in_seg: 13
# *** On index: 271 ***
# 119496
# num_slices_in_seg: 13
# *** On index: 272 ***
# 120070
# num_slices_in_seg: 13
# *** On index: 273 ***
# 112851
# num_slices_in_seg: 13
# *** On index: 274 ***
# 132386
# num_slices_in_seg: 13
# *** On index: 275 ***
# 215930
# num_slices_in_seg: 13
# *** On index: 276 ***
# 112901
# num_slices_in_seg: 13
# *** On index: 277 ***
# 113176
# num_slices_in_seg: 13
# *** On index: 278 ***
# 203607
# num_slices_in_seg: 13
# *** On index: 279 ***
# 213754
# num_slices_in_seg: 13
# *** On index: 280 ***
# 215394
# num_slices_in_seg: 13
# *** On index: 281 ***
# 209831
# num_slices_in_seg: 13
# *** On index: 282 ***
# 131611
# num_slices_in_seg: 13
# *** On index: 283 ***
# 108670
# num_slices_in_seg: 14
# *** On index: 284 ***
# 106553
# num_slices_in_seg: 14
# *** On index: 285 ***
# 130942
# num_slices_in_seg: 14
# *** On index: 286 ***
# 212379
# num_slices_in_seg: 14
# *** On index: 287 ***
# 205405
# num_slices_in_seg: 14
# *** On index: 288 ***
# 106194
# num_slices_in_seg: 14
# *** On index: 289 ***
# 110866
# num_slices_in_seg: 14
# *** On index: 290 ***
# 122590
# num_slices_in_seg: 14
# *** On index: 291 ***
# 204694
# num_slices_in_seg: 14
# *** On index: 292 ***
# 213442
# num_slices_in_seg: 14
# *** On index: 293 ***
# 123247
# num_slices_in_seg: 14
# *** On index: 294 ***
# 104683
# num_slices_in_seg: 14
# *** On index: 295 ***
# 118248
# num_slices_in_seg: 15
# *** On index: 296 ***
# 107002
# num_slices_in_seg: 15
# *** On index: 297 ***
# 109852
# num_slices_in_seg: 15
# *** On index: 298 ***
# 108543
# num_slices_in_seg: 15
# *** On index: 299 ***
# 207526
# num_slices_in_seg: 15
# *** On index: 300 ***
# 212863
# num_slices_in_seg: 15
# *** On index: 301 ***
# 107151
# num_slices_in_seg: 15
# *** On index: 302 ***
# 215677
# num_slices_in_seg: 15
# *** On index: 303 ***
# 209412
# num_slices_in_seg: 15
# *** On index: 304 ***
# 203536
# num_slices_in_seg: 15
# *** On index: 305 ***
# 122025
# num_slices_in_seg: 15
# *** On index: 306 ***
# 210419
# num_slices_in_seg: 15
# *** On index: 307 ***
# 214350
# num_slices_in_seg: 16
# *** On index: 308 ***
# 203500
# num_slices_in_seg: 16
# *** On index: 309 ***
# 213753
# num_slices_in_seg: 16
# *** On index: 310 ***
# 111487
# num_slices_in_seg: 16
# *** On index: 311 ***
# 104248
# num_slices_in_seg: 16
# *** On index: 312 ***
# 211918
# num_slices_in_seg: 16
# *** On index: 313 ***
# 203125
# num_slices_in_seg: 16
# *** On index: 314 ***
# 216399
# num_slices_in_seg: 16
# *** On index: 315 ***
# 100518
# num_slices_in_seg: 17
# *** On index: 316 ***
# 134088
# num_slices_in_seg: 17
# *** On index: 317 ***
# 208294
# num_slices_in_seg: 17
# *** On index: 318 ***
# 201528
# num_slices_in_seg: 17
# *** On index: 319 ***
# 111859
# num_slices_in_seg: 18
# *** On index: 320 ***
# 131910
# num_slices_in_seg: 18
# *** On index: 321 ***
# 119326
# num_slices_in_seg: 18
# *** On index: 322 ***
# 110021
# num_slices_in_seg: 18
# *** On index: 323 ***
# 121333
# num_slices_in_seg: 18
# *** On index: 324 ***
# 107052
# num_slices_in_seg: 18
# *** On index: 325 ***
# 114798
# num_slices_in_seg: 18
# *** On index: 326 ***
# 213046
# num_slices_in_seg: 18
# *** On index: 327 ***
# 218510
# num_slices_in_seg: 18
# *** On index: 328 ***
# 209029
# num_slices_in_seg: 18
# *** On index: 329 ***
# 113918
# num_slices_in_seg: 19
# *** On index: 330 ***
# 105012
# num_slices_in_seg: 19
# *** On index: 331 ***
# 122135
# num_slices_in_seg: 19
# *** On index: 332 ***
# 217245
# num_slices_in_seg: 19
# *** On index: 333 ***
# 208430
# num_slices_in_seg: 19
# *** On index: 334 ***
# 209095
# num_slices_in_seg: 19
# *** On index: 335 ***
# 127399
# num_slices_in_seg: 20
# *** On index: 336 ***
# 134493
# num_slices_in_seg: 20
# *** On index: 337 ***
# 204711
# num_slices_in_seg: 20
# *** On index: 338 ***
# 117534
# num_slices_in_seg: 20
# *** On index: 339 ***
# 203087
# num_slices_in_seg: 20
# *** On index: 340 ***
# 126836
# num_slices_in_seg: 21
# *** On index: 341 ***
# 128156
# num_slices_in_seg: 21
# *** On index: 342 ***
# 200628
# num_slices_in_seg: 21
# *** On index: 343 ***
# 212419
# num_slices_in_seg: 21
# *** On index: 344 ***
# 211677
# num_slices_in_seg: 21
# *** On index: 345 ***
# 203908
# num_slices_in_seg: 21
# *** On index: 346 ***
# 209306
# num_slices_in_seg: 21
# *** On index: 347 ***
# 205089
# num_slices_in_seg: 21
# *** On index: 348 ***
# 217501
# num_slices_in_seg: 21
# *** On index: 349 ***
# 201465
# num_slices_in_seg: 22
# *** On index: 350 ***
# 120410
# num_slices_in_seg: 22
# *** On index: 351 ***
# 116810
# num_slices_in_seg: 22
# *** On index: 352 ***
# 119818
# num_slices_in_seg: 22
# *** On index: 353 ***
# 213972
# num_slices_in_seg: 22
# *** On index: 354 ***
# 105771
# num_slices_in_seg: 23
# *** On index: 355 ***
# 214472
# num_slices_in_seg: 23
# *** On index: 356 ***
# 202014
# num_slices_in_seg: 24
# *** On index: 357 ***
# 112285
# num_slices_in_seg: 24
# *** On index: 358 ***
# 212900
# num_slices_in_seg: 24
# *** On index: 359 ***
# 209116
# num_slices_in_seg: 24
# *** On index: 360 ***
# 207431
# num_slices_in_seg: 24
# *** On index: 361 ***
# 210754
# num_slices_in_seg: 24
# *** On index: 362 ***
# 109189
# num_slices_in_seg: 26
# *** On index: 363 ***
# 207954
# num_slices_in_seg: 26
# *** On index: 364 ***
# 127298
# num_slices_in_seg: 27
# *** On index: 365 ***
# 200931
# num_slices_in_seg: 27
# *** On index: 366 ***
# 204421
# num_slices_in_seg: 27
# *** On index: 367 ***
# 204197
# num_slices_in_seg: 28
# *** On index: 368 ***
# 114182
# num_slices_in_seg: 28
# *** On index: 369 ***
# 107030
# num_slices_in_seg: 28
# *** On index: 370 ***
# 210497
# num_slices_in_seg: 28
# *** On index: 371 ***
# 205591
# num_slices_in_seg: 28
# *** On index: 372 ***
# 122226
# num_slices_in_seg: 28
# *** On index: 373 ***
# 126446
# num_slices_in_seg: 28
# *** On index: 374 ***
# 125663
# num_slices_in_seg: 29
# *** On index: 375 ***
# 111221
# num_slices_in_seg: 29
# *** On index: 376 ***
# 216793
# num_slices_in_seg: 29
# *** On index: 377 ***
# 207366
# num_slices_in_seg: 29
# *** On index: 378 ***
# 105540
# num_slices_in_seg: 30
# *** On index: 379 ***
# 123993
# num_slices_in_seg: 30
# *** On index: 380 ***
# 119029
# num_slices_in_seg: 30
# *** On index: 381 ***
# 218391
# num_slices_in_seg: 30
# *** On index: 382 ***
# 120981
# num_slices_in_seg: 31
# *** On index: 383 ***
# 128534
# num_slices_in_seg: 32
# *** On index: 384 ***
# 102806
# num_slices_in_seg: 34
# *** On index: 385 ***
# 216422
# num_slices_in_seg: 34
# *** On index: 386 ***
# 203010
# num_slices_in_seg: 35
# *** On index: 387 ***
# 121337
# num_slices_in_seg: 36
# *** On index: 388 ***
# 103703
# num_slices_in_seg: 37
# *** On index: 389 ***
# 212718
# num_slices_in_seg: 38
# *** On index: 390 ***
# 218368
# num_slices_in_seg: 38
# *** On index: 391 ***
# 203759
# num_slices_in_seg: 41
# *** On index: 392 ***
# 204909
# num_slices_in_seg: 43
# *** On index: 393 ***
# 201275
# num_slices_in_seg: 44
# *** On index: 394 ***
# 114122
# num_slices_in_seg: 45
# *** On index: 395 ***
# 112041
# num_slices_in_seg: 46
# *** On index: 396 ***
# 115962
# num_slices_in_seg: 46
# *** On index: 397 ***
# 218357
# num_slices_in_seg: 46
# *** On index: 398 ***
# 203166
# num_slices_in_seg: 57
# *** On index: 399 ***
# 119843
# num_slices_in_seg: 62
# *** On index: 400 ***
# 200701
# num_slices_in_seg: 86
# *** On index: 401 ***
# 215002
# num_slices_in_seg: 98
# *** On index: 402 ***
# 217780
# num_slices_in_seg: 99

# %%
# 133076 - problem in accessing derivation image sequence - check later

# %% [markdown]
# # OLD - Get the overlap in terms of number of slices

# %%
 # For each series that overlaps, get the:
 # 1. # of slices with bbox - done
 # 2. # of slices with seg - done
 # 3. # of slices that have both bbox and seg
 # 4. # of slices that have bbox and no seg
 # 5. # of slices that have seg and no bbox

# 1. number of slices with bbox
df_sybil_bbox_num_slices = df_sybil_bbox.groupby('ReferencedSeriesInstanceUID')['ReferencedSOPInstanceUID'].nunique()
df_sybil_num_boxes = df_sybil_bbox_num_slices.to_frame()
df_sybil_num_boxes = df_sybil_num_boxes.reset_index()
df_sybil_num_boxes = df_sybil_num_boxes.rename(columns={'ReferencedSOPInstanceUID':'sybil_num_boxes'})

# 2. number of slices with seg
df_nlstseg_seg_num_slices = df_nlstseg_seg.groupby('SeriesInstanceUID')['ReferencedSOPInstanceUID'].nunique()
df_nlstseg_num_slices = df_nlstseg_seg_num_slices.to_frame()
df_nlstseg_num_slices = df_nlstseg_num_slices.reset_index()
df_nlstseg_num_slices = df_nlstseg_num_slices.rename(columns={'SeriesInstanceUID': 'ReferencedSeriesInstanceUID',
                                                              'ReferencedSOPInstanceUID':'nlstseg_num_slices'})

# since we only care about the series that overlap for now, let's join these two
df_sybil_num_boxes['ReferencedSeriesInstanceUID'] = [str(f) for f in df_sybil_num_boxes['ReferencedSeriesInstanceUID'].values]
df_nlstseg_num_slices['ReferencedSeriesInstanceUID'] = [str(f) for f in df_nlstseg_num_slices['ReferencedSeriesInstanceUID'].values]
ReferencedSeriesInstanceUID_overlap = list(set(df_sybil_num_boxes['ReferencedSeriesInstanceUID'].values) & set(df_nlstseg_num_slices['ReferencedSeriesInstanceUID'].values))

# # keep these
# df_sybil_num_boxes = df_sybil_num_boxes[df_sybil_num_boxes['ReferencedSeriesInstanceUID'].isin(ReferencedSeriesInstanceUID_overlap)]
# df_nlstseg_num_slices = df_nlstseg_num_slices[df_nlstseg_num_slices['ReferencedSeriesInstanceUID'].isin(ReferencedSeriesInstanceUID_overlap)]
# # join
# df_counts = pd.merge(df_sybil_num_boxes, df_nlstseg_num_slices, how='inner', on='ReferencedSeriesInstanceUID')

# 3. number of slices with both bbox and seg
# 4. number of slices with bbox and no seg
# 5. number of slices with seg and no bbox
num_boxes_list = []
num_seg_list = []
overlap_list = []
only_bbox_list = []
only_seg_list = []
for series in ReferencedSeriesInstanceUID_overlap:
  bbox_sop = list(set(df_sybil_bbox[df_sybil_bbox['ReferencedSeriesInstanceUID']==series]['ReferencedSOPInstanceUID'].values))
  seg_sop = list(set(df_nlstseg_seg[df_nlstseg_seg['SeriesInstanceUID']==series]['ReferencedSOPInstanceUID'].values))
  num_boxes = len(list(set(bbox_sop)))
  num_seg = len(list(set(seg_sop)))
  overlap = len(list(set(bbox_sop) & set(seg_sop)))
  only_bbox = len(list(set(bbox_sop) - set(seg_sop)))
  only_seg = len(list(set(seg_sop) - set(bbox_sop)))
  # append
  num_boxes_list.append(num_boxes)
  num_seg_list.append(num_seg)
  overlap_list.append(overlap)
  only_bbox_list.append(only_bbox)
  only_seg_list.append(only_seg)

df_counts = pd.DataFrame()
df_counts['ReferencedSeriesInstanceUID'] = ReferencedSeriesInstanceUID_overlap
df_counts['num_bbox'] = num_boxes_list
df_counts['num_seg'] = num_seg_list
df_counts['overlap'] = overlap_list
df_counts['only_bbox'] = only_bbox_list
df_counts['only_seg'] = only_seg_list

# Calculate the overlap ratio, quick way to filter for low/high overlap:
# overlap_ratio = #overlap_slices / (#bbox_slices + #seg_slices - #overlap_slices)
df_counts['overlap_ratio'] = [f/(g+h-f) for f,g,h in zip(df_counts['overlap'].values, df_counts['num_bbox'].values, df_counts['num_seg'].values)]

# %%
print(np.min(df_counts['overlap_ratio'].values))
print(np.max(df_counts['overlap_ratio'].values))
# Out:
# 0.0
# 1.0

# %%
# Add PatientID, StudyInstanceUID and viewer_url

PatientID_list = []
StudyInstanceUID_list = []
for index, row in df_counts.iterrows():
  series = row['ReferencedSeriesInstanceUID']
  PatientID = df_sybil_bbox[df_sybil_bbox["ReferencedSeriesInstanceUID"]==series]['PatientID'].values[0]
  StudyInstanceUID = df_sybil_bbox[df_sybil_bbox["ReferencedSeriesInstanceUID"]==series]['StudyInstanceUID'].values[0]
  PatientID_list.append(PatientID)
  StudyInstanceUID_list.append(StudyInstanceUID)
df_counts['PatientID'] = PatientID_list
df_counts['StudyInstanceUID'] = StudyInstanceUID_list

# df_sybil_bbox_unique = df_sybil_bbox.drop_duplicates(subset="ReferencedSeriesInstanceUID", keep='first')
# PatientID_list = df_sybil_bbox_unique[df_sybil_bbox_unique['ReferencedSeriesInstanceUID'].isin(ReferencedSeriesInstanceUID_overlap)]['PatientID'].values
# StudyInstanceUID_list = df_sybil_bbox_unique[df_sybil_bbox_unique['ReferencedSeriesInstanceUID'].isin(ReferencedSeriesInstanceUID_overlap)]['StudyInstanceUID'].values

viewer_url_list = ["https://viewers-sandbox-gha-testing.web.app/viewer/?StudyInstanceUIDs=" + f +
                    "&gcp=projects/idc-external-018/locations/us-central1/datasets/sybil_and_nlstseg/dicomStores/sybil_and_nlstseg"
                    for f in StudyInstanceUID_list]

df_counts['PatientID'] = PatientID_list
df_counts['StudyInstanceUID'] = StudyInstanceUID_list
df_counts['viewer_url'] = viewer_url_list

df_counts = df_counts[['PatientID', 'StudyInstanceUID', 'ReferencedSeriesInstanceUID',
                       'num_bbox', 'num_seg', 'overlap', 'only_bbox',	'only_seg', 'overlap_ratio',
                       'viewer_url']]
df_counts = df_counts.sort_values(by=['PatientID', 'StudyInstanceUID', 'ReferencedSeriesInstanceUID'])

# %%
df_counts.head()
# Out:
#     PatientID                                   StudyInstanceUID  \
# 296    100147  1.2.840.113654.2.55.31958452963320032523273261...
# 166    100158  1.2.840.113654.2.55.81185422866512279860334872...
# 145    100242  1.2.840.113654.2.55.22835224307907880875083018...
# 334    100518  1.2.840.113654.2.55.36142141360017014809389003...
# 172    100570  1.2.840.113654.2.55.88862626250387223376057356...
#
#                            ReferencedSeriesInstanceUID  num_bbox  num_seg  \
# 296  1.2.840.113654.2.55.15708941008648745210499888...         8        8
# 166  1.2.840.113654.2.55.31060976780967844152296392...         7        7
# 145  1.2.840.113654.2.55.38995485391900019876570761...         7        3
# 334  1.2.840.113654.2.55.81136962133262551156371928...         4       17
# 172  1.2.840.113654.2.55.32380467633296345717423514...         8       10
#
#      overlap  only_bbox  only_seg  overlap_ratio  \
# 296        8          0         0       1.000000
# 166        7          0         0       1.000000
# 145        3          4         0       0.428571
# 334        0          4        17       0.000000
# 172        7          1         3       0.636364
#
#                                             viewer_url
# 296  https://viewers-sandbox-gha-testing.web.app/vi...
# 166  https://viewers-sandbox-gha-testing.web.app/vi...
# 145  https://viewers-sandbox-gha-testing.web.app/vi...
# 334  https://viewers-sandbox-gha-testing.web.app/vi...
# 172  https://viewers-sandbox-gha-testing.web.app/vi...

# %%
# save to csv, and then will save to BQ table

df_counts.to_csv("/content/sybil_and_nlstseg_overlap_slice_counts.csv")

# %% [markdown]
# # Old

# %%
# Get the segmentation

# %%
# Get a list of the Referenced SOPInstanceUIDs of the NLSTSeg
query = f"""
  SELECT
    *
  FROM
    `idc-external-018.sybil_and_nlstseg.segmentations`
  WHERE
    segmented_SeriesInstanceUID IN UNNEST(@series_list)
"""
job_config = bigquery.QueryJobConfig(query_parameters=[bigquery.ArrayQueryParameter("series_list", "STRING", SeriesInstanceUIDs_list)])
df_seg = client_bq.query(query, job_config=job_config).to_dataframe()

# %%
# We have the per frame functional groups in dicom_all! So somehow have to query and get the ReferencedSOPInstanceUID list

# %%
# We get the segmentation file from the bucket
seg_filename_bucket = os.path.join("gs://nlstseg_seg_and_sr/seg", series_pick + "_SEG.dcm")
seg_filename = os.path.join("/content/seg", series_pick + "_SEG.dcm")
if not os.path.isdir("/content/seg"):
  os.mkdir("/content/seg")
# !gsutil cp $seg_filename_bucket $seg_filename
# Out:
# Copying gs://nlstseg_seg_and_sr/seg/1.2.840.113654.2.55.294795888751210912516507666864500510900_SEG.dcm...
# / [1 files][361.4 KiB/361.4 KiB]
# Operation completed over 1 objects/361.4 KiB.

# %%
# We know which slices have an overlap - by the referencedSOPInstanceUID
# Now we need to get the pixel data for those slices.

seg = pydicom.dcmread(seg_filename)

# Get the pixel array data
mask_data = seg.pixel_array
print(mask_data.shape)

# Need to get the per frame function groups - to know the referencedSOPInstanceUIDs
pffg = seg.PerFrameFunctionalGroupsSequence
num_slices_in_seg = len(pffg)
print('num_slices_in_seg: ' + str(num_slices_in_seg))
pffg_sop_list = []
for n in range(0,num_slices_in_seg):
  sop = pffg[n].DerivationImageSequence[0].SourceImageSequence[0].ReferencedSOPInstanceUID
  pffg_sop_list.append(sop)

# Now create a dataframe with the SOPInstanceUID and the slice index into mask
df_seg = pd.DataFrame()
df_seg['SOPInstanceUID'] = pffg_sop_list
df_seg['mask_slice'] = np.arange(0,len(pffg_sop_list))
# Out:
# (11, 512, 512)
# num_slices_in_seg: 11

# %%
df_seg
# Out:
#                                        SOPInstanceUID  mask_slice
# 0   1.2.840.113654.2.55.13998794245265636889281938...           0
# 1   1.2.840.113654.2.55.92014902492788269776983279...           1
# 2   1.2.840.113654.2.55.84705608724374715224219052...           2
# 3   1.2.840.113654.2.55.30065144618242790472755750...           3
# 4   1.2.840.113654.2.55.33864278056094434912780366...           4
# 5   1.2.840.113654.2.55.82622644398986097265317855...           5
# 6   1.2.840.113654.2.55.24017737918811694854352532...           6
# 7   1.2.840.113654.2.55.19755032706118208307243774...           7
# 8   1.2.840.113654.2.55.66323297372561385302687603...           8
# 9   1.2.840.113654.2.55.29148859922133669813638716...           9
# 10  1.2.840.113654.2.55.91626179069292242355503296...          10

# %%
# Get the gcs_urls of the SOPInstanceUIDs_list - for plotting

query = f"""
  SELECT
    SOPInstanceUID,
    gcs_url
  FROM
    `bigquery-public-data.idc_current.dicom_all`
  WHERE
    SOPInstanceUID IN UNNEST(@SOPInstanceUIDs_list)
"""
job_config = bigquery.QueryJobConfig(query_parameters=[bigquery.ArrayQueryParameter("SOPInstanceUIDs_list", "STRING", SOPInstanceUIDs_list)])
df_sop_urls = client_bq.query(query, job_config=job_config).to_dataframe()

# %%
df_sop_urls
# Out:
#                                        SOPInstanceUID  \
# 0   1.2.840.113654.2.55.66323297372561385302687603...
# 1   1.2.840.113654.2.55.29148859922133669813638716...
# 2   1.2.840.113654.2.55.19755032706118208307243774...
# 3   1.2.840.113654.2.55.82622644398986097265317855...
# 4   1.2.840.113654.2.55.24017737918811694854352532...
# 5   1.2.840.113654.2.55.84705608724374715224219052...
# 6   1.2.840.113654.2.55.30065144618242790472755750...
# 7   1.2.840.113654.2.55.33864278056094434912780366...
# 8   1.2.840.113654.2.55.92014902492788269776983279...
# 9   1.2.840.113654.2.55.13998794245265636889281938...
# 10  1.2.840.113654.2.55.91626179069292242355503296...
#
#                                               gcs_url
# 0   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 1   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 2   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 3   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 4   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 5   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 6   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 7   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 8   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 9   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...
# 10  gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...

# %%
# Now we join df_seg and df_sop_urls

df_plot = pd.merge(df_sop_urls, df_seg, left_on='SOPInstanceUID', right_on='SOPInstanceUID')

# Order by mask_slice
df_plot = df_plot.sort_values(by='mask_slice', ascending=True)

# %%
df_plot
# Out:
#                                        SOPInstanceUID  \
# 9   1.2.840.113654.2.55.13998794245265636889281938...
# 8   1.2.840.113654.2.55.92014902492788269776983279...
# 5   1.2.840.113654.2.55.84705608724374715224219052...
# 6   1.2.840.113654.2.55.30065144618242790472755750...
# 7   1.2.840.113654.2.55.33864278056094434912780366...
# 3   1.2.840.113654.2.55.82622644398986097265317855...
# 4   1.2.840.113654.2.55.24017737918811694854352532...
# 2   1.2.840.113654.2.55.19755032706118208307243774...
# 0   1.2.840.113654.2.55.66323297372561385302687603...
# 1   1.2.840.113654.2.55.29148859922133669813638716...
# 10  1.2.840.113654.2.55.91626179069292242355503296...
#
#                                               gcs_url  mask_slice
# 9   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           0
# 8   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           1
# 5   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           2
# 6   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           3
# 7   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           4
# 3   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           5
# 4   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           6
# 2   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           7
# 0   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           8
# 1   gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...           9
# 10  gs://idc-open-data/2e0111bc-82e6-4285-8daa-cff...          10
